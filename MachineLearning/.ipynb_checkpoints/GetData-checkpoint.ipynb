# %%
# !Pip install snscrape
# !pip install emoji
# !pip install Sastrawi
# !pip install gensim
# Out:
# Ini adalah contoh kalimat dengan tanda baca

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in c:\users\lenovo\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.20.3)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# aiodns                             3.0.0
# aiohttp                            3.7.0
# aiohttp-socks                      0.4.1
# aiosignal                          1.2.0
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              3.6.1
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# async-generator                    1.10
# async-timeout                      3.0.1
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# bs4                                0.0.1
# cached-property                    1.5.2
# cchardet                           2.1.7
# certifi                            2021.10.8
# cffi                               1.14.6
# chardet                            3.0.4
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.4
# coloredlogs                        14.3
# comtypes                           1.1.10
# conda                              4.10.3
# conda-build                        3.21.6
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       3.4.8
# cssselect                          1.1.0
# cycler                             0.10.0
# Cython                             0.29.32
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dask                               2021.10.0
# dataclasses                        0.6
# dateparser                         1.1.1
# debugpy                            1.4.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# demjson3                           3.0.5
# diff-match-patch                   20200713
# distributed                        2021.10.0
# Django                             4.1.5
# docopt                             0.6.2
# docutils                           0.17.1
# elastic-transport                  8.1.2
# elasticsearch                      8.2.3
# emoji                              2.2.0
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# facebook-scraper                   0.2.57
# fake-useragent                     0.1.11
# fastcache                          1.1.0
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              1.1.2
# fonttools                          4.25.0
# frozenlist                         1.3.0
# fs                                 2.4.16
# fsspec                             2021.10.1
# fst-pso                            1.8.1
# funcy                              1.17
# future                             0.18.2
# FuzzyTM                            2.0.5
# gapminder                          0.1
# gensim                             4.3.0
# geographiclib                      1.52
# geopy                              2.2.0
# gevent                             21.8.0
# glob2                              0.7
# google-play-scraper                1.1.0
# googletransx                       2.4.2
# greenlet                           1.1.1
# h11                                0.12.0
# h5py                               3.2.1
# HeapDict                           1.0.1
# html5lib                           1.1
# httpcore                           0.15.0
# httpx                              0.23.0
# humanfriendly                      10.0Note: you may need to restart the kernel to use updated packages.
#
# idna                               3.2
# imagecodecs                        2021.8.26
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.8.1
# inflection                         0.5.1
# iniconfig                          1.1.1
# insta-scrape                       2.1.2
# instagram-explore                  0.3.0
# instagramy                         4.5
# instaloader                        4.9.3
# instalooter                        2.4.4
# instascrape                        0.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# joblib                             1.1.0
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.8.1
# jupyter-server                     1.4.1
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# keyring                            23.1.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# menuinst                           1.4.18
# miniful                            0.0.6
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multidict                          6.0.2
# multipledispatch                   0.6.0
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# mysql-connector                    2.2.9
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.20.3
# numpydoc                           1.1.0
# oauthlib                           3.2.0
# olefile                            0.46
# openpyxl                           3.0.9
# outcome                            1.2.0
# packaging                          21.0
# pandas                             1.3.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parse                              1.19.0
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                21.2.4
# pkginfo                            1.7.1
# plotly                             5.11.0
# pluggy                             0.13.1
# ply                                3.11
# poyo                               0.5.0
# preprocessor                       1.1.3
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pybrowsers                         0.4.1
# pycares                            4.2.0
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# pydocstyle                         6.1.1
# pyee                               8.2.2
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# pyFUME                             0.2.25
# Pygments                           2.10.0
# PyJWT                              2.1.0
# pyLDAvis                           3.3.1
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# pyppeteer                          1.0.2
# pyquery                            1.4.3
# pyreadline                         2.1
# pyreadline3                        3.4.1
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-dotenv                      0.20.0
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# python-socks                       2.0.3
# pytz                               2021.3
# pytz-deprecation-shim              0.1.0.post0
# PyWavelets                         1.1.1
# pywin32                            303
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# regex                              2021.8.3
# requests                           2.28.0
# requests-html                      0.10.0
# requests-oauthlib                  1.3.1
# rfc3986                            1.5.0
# rope                               0.19.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# Sastrawi                           1.0.1
# schedule                           1.1.0
# scikit-image                       0.18.3
# scikit-learn                       0.24.2
# scikit-learn-intelex               2021.20210714.120553
# scipy                              1.7.1
# seaborn                            0.11.2
# selenium                           4.3.0
# Send2Trash                         1.8.0
# setuptools                         58.0.4
# simpful                            2.9.0
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sklearn                            0.0.post1
# smart-open                         6.3.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# snscrape                           0.4.3.20220106
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# statsmodels                        0.12.2
# swifter                            1.2.0
# sympy                              1.9
# tables                             3.6.1
# TBB                                0.2
# tblib                              1.7.0
# tenacity                           6.3.1
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textblob                           0.17.1
# textdistance                       4.2.1
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.0
# trio                               0.21.0
# trio-websocket                     0.9.2
# tweepy                             4.10.0
# tweet-preprocessor                 0.6.0
# twint                              2.1.21
# typed-ast                          1.4.3
# typing-extensions                  3.10.0.2
# tzdata                             2022.1
# tzlocal                            4.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            1.26.7
# validate-email                     1.3
# verboselogs                        1.7
# w3lib                              1.22.0
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webdriver-manager                  3.8.0
# webencodings                       0.5.1
# websockets                         10.3
# Werkzeug                           2.0.2
# wheel                              0.37.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.2.2
# wrapt                              1.12.1
# wsproto                            1.1.0
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.24.9
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# yarl                               1.7.2
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0

# %%
# %%capture
# !git clone https://github.com/JustAnotherArchivist/snscrape.git
# %cd /content/snscrape
# !python -m pip install /content/snscrape

# %%
import snscrape.modules.twitter as snt 

import pandas as pd 
import numpy as np
import re
import string
import emoji

# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


from tqdm import tqdm 

from nltk.tokenize import word_tokenize
import nltk

import ast 

# from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

import gensim
from gensim import corpora, models

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# Tahapan Pengumpulan Data

# %%
query = "resesi since:2022-10-01 until:2022-10-16 lang:id"
tweets = [] 
limit = 2

query = snt.TwitterSearchScraper('from:elonmusk', top=True).get_items()
for i, tweet in enumerate(query):
  print(tweet.rawContent)
  if i > limit: break
# for tweet in snt.TwitterSearchScraper(query, top = True).get_items(): 
#     print(vars(tweet)) 
#     break 
#     if len(tweets) == limit: 
#         break 
#     else: tweets.append([tweet.date, tweet.content]) 
#     tweet_data = pd.DataFrame(tweets, columns=["Date", "Tweets"])
# Out:
# Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3Aelonmusk&count=100&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel: non-200 status code
# 4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3Aelonmusk&count=100&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel failed, giving up.
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22532/2033566014.py in <module>
#       4
#       5 query = snt.TwitterSearchScraper('from:elonmusk', top=True).get_items()
# ----> 6 for i, tweet in enumerate(query):
#       7   print(tweet.rawContent)
#       8   if i > limit: break
#
# ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py in get_items(self)
#     678                         del paginationParams['tweet_search_mode']
#     679
# --> 680                 for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', params, paginationParams, cursor = self._cursor):
#     681                         yield from self._instructions_to_tweets(obj)
#     682
#
# ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py in _iter_api_data(self, endpoint, params, paginationParams, cursor, direction)
#     367                 while True:
#     368                         _logger.info(f'Retrieving scroll page {cursor}')
# --> 369                         obj = self._get_api_data(endpoint, reqParams)
#     370                         yield obj
#     371
#
# ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py in _get_api_data(self, endpoint, params)
#     337         def _get_api_data(self, endpoint, params):
#     338                 self._ensure_guest_token()
# --> 339                 r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = self._check_api_response)
#     340                 try:
#     341                         obj = r.json()
#
# ~\anaconda3\lib\site-packages\snscrape\base.py in _get(self, *args, **kwargs)
#     214
#     215         def _get(self, *args, **kwargs):
# --> 216                 return self._request('GET', *args, **kwargs)
#     217
#     218         def _post(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\snscrape\base.py in _request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects)
#     210                         msg = f'{self._retries + 1} requests to {req.url} failed, giving up.'
#     211                         logger.fatal(msg)
# --> 212                         raise ScraperException(msg)
#     213                 raise RuntimeError('Reached unreachable code')
#     214
#
# ScraperException: 4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3Aelonmusk&count=100&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel failed, giving up.

# %%
tweet_data.to_csv('resesi2.csv', index = None)

# %%
dfc = pd.read_csv("resesi1.csv");

# %%
# dfc = pd.read_csv("resesi1.csv");
# dfc = tweet_data
dfc['Tweets'][0]
# Out:
# 'seiring dg Resesi proyeksi gelap ekonomi global adlg kunci logis dri penerapan sistem ekonomi kapitalisme yg mulai menguasai dunia pd abad ke-18 Apalagi setelah Amerika menaklukkan Rival ideologix yaitu monarki,selengkapnya di serba-serbi MMC https://t.co/Ioec3Eczmr\n#IslamKaffah https://t.co/LwNSBD3klA'

# %%
dfc
# Out:
#                            Date             User  Number of likes  \
# 0     2022-10-15 23:57:38+00:00  SurfaniSurfani3                0
# 1     2022-10-15 23:55:55+00:00      UmiHafizha1                1
# 2     2022-10-15 23:55:14+00:00    latifajulia77                1
# 3     2022-10-15 23:55:08+00:00        PDemokrat              142
# 4     2022-10-15 23:53:49+00:00      BELIEVEIN93                0
# ...                         ...              ...              ...
# 7612  2022-10-11 00:06:07+00:00   IndovisionAsia                0
# 7613  2022-10-11 00:05:24+00:00     RadioSmartFM                0
# 7614  2022-10-11 00:04:48+00:00      sugarhnybee                0
# 7615  2022-10-11 00:01:07+00:00        tvOneNews                2
# 7616  2022-10-11 00:00:00+00:00  officialnova_id                0
#
#              Tweeted from                                             Tweets
# 0     Twitter for Android  seiring dg Resesi proyeksi gelap ekonomi globa...
# 1     Twitter for Android  IMF memproyeksi ekonomi global akan gelap pd t...
# 2     Twitter for Android  ekonomi global Akan Gelap pd 2023 krn merugi 4...
# 3     Twitter for Android  Presiden ke-6 RI, Susilo Bambang Yudhoyono mer...
# 4     Twitter for Android  @jek___ Sebelum 2015 udha ngerasain resesi wkw...
# ...                   ...                                                ...
# 7612              dlvr.it  Bank Dunia dan IMF Ulangi Peringatan soal Rese...
# 7613            TweetDeck  NOW AIRING\n\n#SmartBusinessTalk bersama @Tung...
# 7614  Twitter for Android  Kalo amit2 jadi resesi yg mo nikah tahun depan...
# 7615              dlvr.it  Harga Minyak Merosot Hampir Dua Persen Pada Ak...
# 7616            TweetDeck  Zodiak yang kemungkinan besar bertahan saat re...
#
# [7617 rows x 5 columns]

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7617 entries, 0 to 7616
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             7617 non-null   object
#  1   User             7617 non-null   object
#  2   Number of likes  7617 non-null   int64
#  3   Tweeted from     7617 non-null   object
#  4   Tweets           7617 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 297.7+ KB

# %%
# dfc = dfc.drop('Number of likes', axis=1)
# dfc = dfc.drop('User', axis=1)
# dfc = dfc.drop('Tweeted from', axis=1)

# %% [markdown]
# Tahapan 2 Prepocessing
# 2.1. stopword(Menghapus tanda @,http link,hastag,tanda baca petik, tanda seru, tanda tanya, spasi, nomor, emoji)
# 2.2. Lower Case
# 2.3. Tokenisasi

# %%
# try:
#     dfc = dfc.drop('clear', axis=1)
# except:
#     print("")
clean_tweets = []
token_tweets = []
freq_words = []

# stopword
stop_factory = StopWordRemoverFactory().get_stop_words() #load defaul stopword
more_stopword = ['•',"stengah", "kopit", "china","g","yaaaaa","gengs","gada","dgn",
"nich","yg","padan", "juoro","nya","js","kl","","co","ga","lg","gw","jg","walu",
"grrabbpoodd","klo","jeben","makane","kakean","sek","mb","skp","tpi","bgt","lgi",
"lu","rb","rban","mura","pd","nih","lii","enel","dr","exo","ipo","trus","d","shm",
"skrg","byk","mang","ots","dah""dg","bp","n","arsjadrasjid","mmc"] #menambahkan stopword
data_stopword = stop_factory + more_stopword #menggabungkan stopword

for tweet in tqdm(dfc['Tweets']):
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = tweet.replace("#", "").replace("_", " ") #Remove hashtag sign but keep the text
    tweet = re.sub(r"\d+", "", tweet) # Remove number
    tweet = ''.join(c for c in tweet if c not in emoji.EMOJI_DATA) #Remove Emojis
    tweet = tweet.replace('"','') #remove quotation mark
    tweet = tweet.lower() #Lower Case
    tweet = tweet.strip() # Remove Whitespace
    tweet = tweet.translate(str.maketrans("","",string.punctuation)) #Remove Punctuation 
 
    dictionary = ArrayDictionary(data_stopword)
    swr = StopWordRemover(dictionary)
    tweet = swr.remove(tweet)
    
    #Tokenization
    tokens = nltk.tokenize.word_tokenize(tweet)
    tweet = " ".join(tokens) #Disatukan Kembali
    
    freq_words.append(nltk.FreqDist(word_tokenize(tweet)))
    
    token_tweets.append(tokens)
    clean_tweets.append(tweet)
dfc['clear'] = clean_tweets
dfc['token_tweets'] = token_tweets
dfc['freq_words'] = freq_words

all_freq_words = nltk.FreqDist(sum(dfc['clear'].map(word_tokenize), []))

dfc
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 7617/7617 [00:01<00:00, 3962.15it/s]
#                            Date             User  Number of likes  \
# 0     2022-10-15 23:57:38+00:00  SurfaniSurfani3                0
# 1     2022-10-15 23:55:55+00:00      UmiHafizha1                1
# 2     2022-10-15 23:55:14+00:00    latifajulia77                1
# 3     2022-10-15 23:55:08+00:00        PDemokrat              142
# 4     2022-10-15 23:53:49+00:00      BELIEVEIN93                0
# ...                         ...              ...              ...
# 7612  2022-10-11 00:06:07+00:00   IndovisionAsia                0
# 7613  2022-10-11 00:05:24+00:00     RadioSmartFM                0
# 7614  2022-10-11 00:04:48+00:00      sugarhnybee                0
# 7615  2022-10-11 00:01:07+00:00        tvOneNews                2
# 7616  2022-10-11 00:00:00+00:00  officialnova_id                0
#
#              Tweeted from                                             Tweets  \
# 0     Twitter for Android  seiring dg Resesi proyeksi gelap ekonomi globa...
# 1     Twitter for Android  IMF memproyeksi ekonomi global akan gelap pd t...
# 2     Twitter for Android  ekonomi global Akan Gelap pd 2023 krn merugi 4...
# 3     Twitter for Android  Presiden ke-6 RI, Susilo Bambang Yudhoyono mer...
# 4     Twitter for Android  @jek___ Sebelum 2015 udha ngerasain resesi wkw...
# ...                   ...                                                ...
# 7612              dlvr.it  Bank Dunia dan IMF Ulangi Peringatan soal Rese...
# 7613            TweetDeck  NOW AIRING\n\n#SmartBusinessTalk bersama @Tung...
# 7614  Twitter for Android  Kalo amit2 jadi resesi yg mo nikah tahun depan...
# 7615              dlvr.it  Harga Minyak Merosot Hampir Dua Persen Pada Ak...
# 7616            TweetDeck  Zodiak yang kemungkinan besar bertahan saat re...
#
#                                                   clear  \
# 0     seiring dg resesi proyeksi gelap ekonomi globa...
# 1     imf memproyeksi ekonomi global gelap tahun ini...
# 2     ekonomi global gelap krn merugi t ud akibat re...
# 3     presiden ri susilo bambang yudhoyono merasa re...
# 4     udha ngerasain resesi wkwkwk bismillah siap me...
# ...                                                 ...
# 7612  bank dunia imf ulangi peringatan soal resesi g...
# 7613  now airing smartbusinesstalk bersama yang memb...
# 7614  kalo amit jadi resesi mo nikah tahun depan gmn...
# 7615  harga minyak merosot hampir persen akhir perda...
# 7616  zodiak kemungkinan besar bertahan resesi virgo...
#
#                                            token_tweets  \
# 0     [seiring, dg, resesi, proyeksi, gelap, ekonomi...
# 1     [imf, memproyeksi, ekonomi, global, gelap, tah...
# 2     [ekonomi, global, gelap, krn, merugi, t, ud, a...
# 3     [presiden, ri, susilo, bambang, yudhoyono, mer...
# 4     [udha, ngerasain, resesi, wkwkwk, bismillah, s...
# ...                                                 ...
# 7612  [bank, dunia, imf, ulangi, peringatan, soal, r...
# 7613  [now, airing, smartbusinesstalk, bersama, yang...
# 7614  [kalo, amit, jadi, resesi, mo, nikah, tahun, d...
# 7615  [harga, minyak, merosot, hampir, persen, akhir...
# 7616  [zodiak, kemungkinan, besar, bertahan, resesi,...
#
#                                              freq_words
# 0     {'seiring': 1, 'dg': 1, 'resesi': 1, 'proyeksi...
# 1     {'imf': 1, 'memproyeksi': 1, 'ekonomi': 2, 'gl...
# 2     {'ekonomi': 2, 'global': 1, 'gelap': 1, 'krn':...
# 3     {'presiden': 1, 'ri': 1, 'susilo': 1, 'bambang...
# 4     {'udha': 1, 'ngerasain': 1, 'resesi': 1, 'wkwk...
# ...                                                 ...
# 7612  {'bank': 1, 'dunia': 1, 'imf': 1, 'ulangi': 1,...
# 7613  {'now': 1, 'airing': 1, 'smartbusinesstalk': 1...
# 7614  {'kalo': 1, 'amit': 1, 'jadi': 1, 'resesi': 1,...
# 7615  {'harga': 1, 'minyak': 1, 'merosot': 1, 'hampi...
# 7616  {'zodiak': 1, 'kemungkinan': 1, 'besar': 1, 'b...
#
# [7617 rows x 8 columns]

# %% [markdown]
# 2.4. Steaming
# mengubah kata berimbuhan menjadi kata dasar dengan library sastrawi

# %%
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in dfc['token_tweets']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

dfc['stemmed_tweet'] = dfc['token_tweets'].swifter.apply(get_stemmed_term)
print(dfc['stemmed_tweet'])
# Out:
# 14761
# ------------------------
# seiring : iring
# dg : dg
# resesi : resesi
# proyeksi : proyeksi
# gelap : gelap
# ekonomi : ekonomi
# global : global
# adlg : adlg
# kunci : kunci
# logis : logis
# dri : dri
# penerapan : terap
# sistem : sistem
# kapitalisme : kapitalisme
# mulai : mulai
# menguasai : kuasa
# dunia : dunia
# abad : abad
# apalagi : apalagi
# amerika : amerika
# menaklukkan : takluk
# rival : rival
# ideologix : ideologix
# monarkiselengkapnya : monarkiselengkapnya
# serbaserbi : serbaserbi
# islamkaffah : islamkaffah
# imf : imf
# memproyeksi : proyeksi
# tahun : tahun
# ini : ini
# diakibatkan : akibat
# banyak : banyak
# covid : covid
# imbas : imbas
# invsi : invsi
# rusi : rusi
# ukrina : ukrina
# mampukah : mampu
# mengatasinya : atas
# simak : simak
# videonya : video
# mmc : mmc
# krn : krn
# merugi : rugi
# t : t
# ud : ud
# akibat : akibat
# penyebabx : penyebabx
# amp : amp
# dihadapkan : hadap
# ancaman : ancam
# krisis : krisis
# invasi : invasi
# rusia : rusia
# ukraina : ukraina
# perubahan : ubah
# ikliminilh : ikliminilh
# akibt : akibt
# presiden : presiden
# ri : ri
# susilo : susilo
# bambang : bambang
# yudhoyono : yudhoyono
# merasa : rasa
# resah : resah
# hambat : hambat
# upaya : upaya
# atasi : atas
# warming : warming
# dan : dan
# justru : justru
# sibuk : sibuk
# masalah : masalah
# geopolitik : geopolitik
# kian : kian
# runcing : runcing
# lantas : lantas
# seberapa : berapa
# besar : besar
# perhatian : perhati
# pemimpin : pimpin
# utk : utk
# selamatkan : selamat
# bumi : bumi
# udha : udha
# ngerasain : ngerasain
# wkwkwk : wkwkwk
# bismillah : bismillah
# siap : siap
# menjalani : jalan
# menghadapinya : hadap
# yang : yang
# lahir : lahir
# aja : aja
# biasa : biasa
# she : she
# said : said
# depan : depan
# mau : mau
# loh : loh
# yakin : yakin
# resign : resign
# arghhhh : arghhhh
# diprediksi : prediksi
# mengatasi : atas
# kapitalis : kapitalis
# akan : akan
# thn : thn
# selengkaonya : selengkaonya
# sedang : sedang
# mengalami : alami
# berikut : ikut
# si : si
# anjing : anjing
# mending : mending
# suruh : suruh
# kerja : kerja
# nabung : nabung
# soalnya : soal
# war : war
# sama : sama
# netijen : netijen
# gak : gak
# bakal : bakal
# bikin : bikin
# tabungan : tabung
# gendut : gendut
# thx : thx
# gue : gue
# jadi : jadi
# paham : paham
# dikit : dikit
# sm : sm
# semoga : moga
# aku : aku
# kita : kita
# semua : semua
# aman : aman
# bintang : bintang
# mares : mares
# balikan : balik
# islam : islam
# kaffah : kaffah
# buat : buat
# klen : klen
# ajakajak : ajakajak
# hangout : hangout
# sorry : sorry
# tolak : tolak
# persiapan : siap
# menghadapi : hadap
# bayangin : bayangin
# kalo : kalo
# orang : orang
# sampai : sampai
# indonesia : indonesia
# keluar : keluar
# statement : statement
# bersyukur : syukur
# kena : kena
# di : di
# negara : negara
# pedalaman : dalam
# afrika : afrika
# makan : makan
# lho : lho
# bener : bener
# sih : sih
# tinggal : tinggal
# lainnya : lain
# kiat : kiat
# umkm : umkm
# hadapi : hadap
# pakar : pakar
# sebut : sebut
# tak : tak
# berdampak : dampak
# langsung : langsung
# alasannya : alas
# tempobisnis : tempobisnis
# ngapain : ngapain
# mesti : mesti
# takut : takut
# prediksi : prediksi
# emang : emang
# selama : lama
# hidupmu : hidup
# sulit : sulit
# sekarang : sekarang
# penghasilanmu : hasil
# dulu : dulu
# antum : antum
# udah : udah
# duluan : duluan
# ye : ye
# harga : harga
# minyak : minyak
# mentah : mentah
# anjlok : anjlok
# pekan : pekan
# kekhawatiran : khawatir
# merebak : rebak
# hargaminyakbumi : hargaminyakbumi
# minus : minus
# yaahahaha : yaahahaha
# lo : lo
# juga : juga
# terjadi : jadi
# berkali : kali
# kali : kali
# idup : idup
# ya : ya
# plis : plis
# bukan : bukan
# resepsi : resepsi
# gua : gua
# tkutnya : tkutnya
# cuman : cuman
# gimmick : gimmick
# doang : doang
# skarang : skarang
# spekulasi : spekulasi
# gk : gk
# trdampak : trdampak
# kurang : kurang
# apa : apa
# coba : coba
# cadangan : cadang
# bnyk : bnyk
# lahan : lahan
# pertanian : tani
# bisa : bisa
# jd : jd
# lumbung : lumbung
# pangan : pangan
# luas : luas
# mandiri : mandiri
# tnpa : tnpa
# trgantung : trgantung
# iya : iya
# lupa : lupa
# berintegritas : integritas
# ngelola : ngelola
# barengbareng : barengbareng
# yuk : yuk
# anak : anak
# indo : indo
# gitu : gitu
# yah : yah
# membayangi : bayang
# sektor : sektor
# pilihan : pilih
# investasi : investasi
# investor : investor
# pemula : mula
# iklim : iklim
# channel : channel
# i : i
# didn : didn
# ’ :
# know : know
# how : how
# powerful : powerful
# starlink : starlink
# was : was
# till : till
# this : this
# bisabisa : bisabisa
# bubar : bubar
# tongkrongan : tongkrong
# fly : fly
# over : over
# pasar : pasar
# klender : klender
# favorit : favorit
# aing : aing
# kalau : kalau
# pedagang : dagang
# no : no
# more : more
# indocafe : indocafe
# cappuccino : cappuccino
# pake : pake
# susu : susu
# kental : kental
# manis : manis
# bendera : bendera
# jangan : jangan
# anda : anda
# salah : salah
# satu : satu
# terkena : kena
# dampak : dampak
# negatif : negatif
# selengkapnya : lengkap
# ketua : ketua
# dpr : dpr
# puan : puan
# maharani : maharani
# mengatakan : kata
# perlu : perlu
# adanya : ada
# multi : multi
# lateral : lateral
# mengantisipasi : antisipasi
# saat : saat
# tengah : tengah
# mengancam : ancam
# terus : terus
# beneran : beneran
# mungkin : mungkin
# menjadi : jadi
# sedikit : sedikit
# lebih : lebih
# anggap : anggap
# tantangan : tantang
# masalahnya : masalah
# paling : paling
# sakit : sakit
# masyarakat : masyarakat
# menengah : tengah
# bawah : bawah
# dianggap : anggap
# sepele : sepele
# konten : konten
# malah : malah
# fomo : fomo
# womg : womg
# cilik : cilik
# arep : arep
# mikir : mikir
# wis : wis
# enek : enek
# wektune : wektune
# ra : ra
# uripe : uripe
# yo : yo
# susah : susah
# jalani : jalan
# ae : ae
# urip : urip
# kan : kan
# pamcen : pamcen
# kadang : kadang
# untung : untung
# sing : sing
# pemting : pemting
# survive : survive
# hidupnya : hidup
# punya : punya
# segalanya : segala
# guys : guys
# beli : beli
# mobil : mobil
# awal : awal
# engga : engga
# papa : papa
# yg : yg
# blng : blng
# bravo : bravo
# b : b
# ehh : ehh
# kbarnya : kbarnya
# taon : taon
# depaneamng : depaneamng
# soal : soal
# percaya : percaya
# enggak : enggak
# influencer : influencer
# ngeributin : ngeributin
# tp : tp
# emg : emg
# ngga : ngga
# salahnya : salah
# diomongin : diomongin
# nakutin : nakutin
# intinya : inti
# hemat : hemat
# invest : invest
# bagus : bagus
# pokoknya : pokok
# biar : biar
# u : u
# stabil : stabil
# sukur : sukur
# kaya : kaya
# bang : bang
# gegara : gegara
# perang : perang
# gembel : gembel
# smua : smua
# bila : bila
# signifikan : signifikan
# okay : okay
# bagaimana : bagaimana
# suatu : suatu
# kejadian : jadi
# bencana : bencana
# sertai : serta
# semananjung : semananjung
# korea : korea
# makin : makin
# panas : panas
# lama : lama
# hah : hah
# ortu : ortu
# masukin : masukin
# kuliah : kuliah
# fakultas : fakultas
# jor : jor
# joran : joran
# daly : daly
# fed : fed
# dalam : dalam
# diperlukan : perlu
# atau : atau
# terasa : asa
# dari : dari
# ngebahas : ngebahas
# seenggaknya : enggak
# dapet : dapet
# ilmu : ilmu
# baru : baru
# kondisi : kondisi
# cara : cara
# menyikapinya : sikap
# benerbener : benerbener
# minimal : minimal
# diri : diri
# sendiri : sendiri
# temenmu : temenmu
# nder : nder
# cba : cba
# liat : liat
# jga : jga
# kak : kak
# feli : feli
# kyk : kyk
# ngasih : ngasih
# summary : summary
# saran : saran
# gtu : gtu
# katanya : kata
# keluargaku : keluarga
# bertahan : tahan
# nnti : nnti
# nunggu : nunggu
# turun : turun
# mati : mati
# keknya : kek
# waktu : waktu
# ga : ga
# sadar : sadar
# pernah : pernah
# buruk : buruk
# sampe : sampe
# berantem : antem
# hampir : hampir
# tiap : tiap
# hari : hari
# bahkan : bahkan
# penyebab : sebab
# satunya : satu
# dirumah : rumah
# kakakku : kakak
# merantau : rantau
# pendapatan : dapat
# sehari : hari
# cm : cm
# k : k
# gpp : gpp
# kalanya : kala
# pengaruhi : pengaruh
# privat : privat
# siapkan : siap
# tiga : tiga
# rencana : rencana
# sumpah : sumpah
# trend : trend
# if : if
# we : we
# never : never
# try : try
# bisnis : bisnis
# kulia : kulia
# itu : itu
# tu : tu
# berhasil : hasil
# ngusir : ngusir
# fear : fear
# mongering : mongering
# potensi : potensi
# sandiaga : sandiaga
# uno : uno
# kuatkan : kuat
# kolaborasi : kolaborasi
# sindonews : sindonews
# bukanberitabiasa : bukanberitabiasa
# mo : mo
# isu : isu
# mbok : mbok
# dipikir : pikir
# masuk : masuk
# logika : logika
# recehan : receh
# digoreng : goreng
# mulu : mulu
# bingung : bingung
# msh : msh
# laen : laen
# msti : msti
# dipikirin : dipikirin
# jok : jok
# diluar : luar
# negeri : negeri
# pd : pd
# bahas : bahas
# lah : lah
# lbh : lbh
# bermanfaat : manfaat
# dpn : dpn
# drop : drop
# ayolah : ayo
# bermutu : mutu
# bedanya : beda
# perjuangan : juang
# huruf : huruf
# p : p
# kata : kata
# terima : terima
# kasih : kasih
# atas : atas
# tahunnya : tahun
# trijaya : trijaya
# cellsemoga : cellsemoga
# kedepan : depan
# toko : toko
# rame : rame
# diera : era
# negera : negera
# haha : haha
# berani : berani
# zona : zona
# nyaman : nyaman
# prestasi : prestasi
# untuk : untuk
# melangkah : lang
# maju : maju
# see : see
# you : you
# again : again
# tjc : tjc
# garagara : garagara
# temen : temen
# suka : suka
# panik : panik
# pasti : pasti
# dikomen : dikomen
# ntar : ntar
# taun : taun
# gini : gin
# kamar : kamar
# seminggu : minggu
# terpapar : papar
# ttg : ttg
# selesai : selesai
# kencengin : kencengin
# iket : iket
# pinggang : pinggang
# koh : koh
# raymond : raymond
# ngomong : ngomong
# paquito : paquito
# close : close
# the : the
# door : door
# berat : berat
# pala : pala
# belakang : belakang
# infrastruktur : infrastruktur
# htuang : htuang
# percuma : percuma
# harunsya : harunsya
# nilai : nilai
# surplus : surplus
# prinsip : prinsip
# teknik : teknik
# idntsri : idntsri
# macro : macro
# maklum : maklum
# bapak : bapak
# berlatar : latar
# kehutanan : hutan
# tahu : tahu
# menahu : nahu
# main : main
# hajar : hajar
# rugi : rugi
# bangsa : bangsa
# indoensia : indoensia
# gimana : gimana
# tuh : tuh
# mana : mana
# ori : ori
# mendukung : dukung
# ba : ba
# app : app
# prem : prem
# dong… : dong
# resasi : resasi
# dahlah : dah
# ngurus : ngurus
# pemerintah : perintah
# pusat : pusat
# bos : bos
# perusstartup : perusstartup
# gede : gede
# pikirin : pikirin
# gmn : gmn
# caranya : cara
# tetap : tetap
# jualan : jual
# laku : laku
# pegawai : pegawai
# atasanmu : atas
# tba : tba
# phk : phk
# upgrade : upgrade
# ketrampilanskill : ketrampilanskill
# bernilai : nila
# cuma : cuma
# gagal : gagal
# pdkt : pdkt
# chancenya : chancenya
# kecil : kecil
# prepare : prepare
# cari : cari
# isi : isi
# catetannya : catetannya
# pajero : pajero
# umpetin : umpetin
# kelar : kelar
# harley : harley
# davidson : davidson
# taro : taro
# digarasi : garasi
# kaos : kaos
# balenciaga : balenciaga
# pindah : pindah
# rak : rak
# polos : polos
# syopi : syopi
# slow : slow
# but : but
# sure : sure
# saham : saham
# meta : meta
# lambat : lambat
# laun : laun
# pelanpelan : pelanpelan
# poin : poin
# yaitu : yaitu
# per : per
# minggu : minggu
# why : why
# karena : karena
# russoukrainian : russoukrainian
# inflasi : inflasi
# usd : usd
# gbp : gbp
# eur : eur
# interest : interest
# rate : rate
# bla : bla
# problemnya : problem
# baca : baca
# denger : denger
# tntng : tntng
# gabisa : gabisa
# amit : amit
# deh : deh
# kepikiran : pikir
# anj : anj
# akhir : akhir
# ialah : ialah
# menarik : tarik
# modal : modal
# membaca : baca
# berita : berita
# issue : issue
# nasional : nasional
# unto : unto
# international : international
# ada : ada
# transisi : transisi
# menghasilkan : hasil
# sebaliknya : balik
# “ :
# ” :
# … :
# yes : yes
# it : it
# still : still
# can : can
# get : get
# worse : worse
# tho : tho
# ta : ta
# mas : mas
# ibu : ibu
# lesti : lesti
# rujuk : rujuk
# ditakutin : ditakutin
# lipstick : lipstick
# padahal : padahal
# mah : mah
# banyaaaaak : banyaaaaak
# gatau : gatau
# effect : effect
# pas : pas
# halah : halah
# eblas : eblas
# sbg : sbg
# org : org
# bodoh : bodoh
# perekonomian : ekonomi
# pgn : pgn
# diskusi : diskusi
# diskusiin : diskusiin
# hal : hal
# private : private
# y : y
# jam : jam
# caloncalon : caloncalon
# sangkuterssss : sangkuterssss
# second : second
# liner : liner
# bluechip : bluechip
# risknya : risknya
# tetep : tetep
# bulan : bulan
# merah : merah
# teros : ros
# cutloss : cutloss
# dpt : dpt
# cash : cash
# serok : serok
# depannya : depan
# wkwk : wkwk
# pusing : pusing
# gasih : gasih
# konser : konser
# black : black
# pink : pink
# dibulan : bulan
# tds : tds
# pki : pki
# lawak : lawak
# sbnrnya : sbnrnya
# situ : situ
# terancam : ancam
# invenstasi : invenstasi
# jelas : jelas
# kondisinya : kondisi
# terulang : ulang
# udh : udh
# batin : batin
# blm : blm
# waktunya : waktu
# dompet : dompet
# tiris : tiris
# misal : misal
# piscok : piscok
# membantu : bantu
# suami : suami
# ih : ih
# baby : baby
# cough : cough
# bahaya : bahaya
# pdhal : pdhal
# dlu : dlu
# batuk : batuk
# minum : minum
# beres : beres
# alhamdulillah : alhamdulillah
# kenapa : kenapa
# kayanya : kaya
# consumer : consumer
# goods : goods
# pada : pada
# ngawur : ngawur
# bahannya : bahan
# gara : gara
# bantu : bantu
# meringankan : ringan
# ditahantahan : ditahantahan
# uangnya : uang
# spend : spend
# daya : daya
# tiket : tiket
# kpop : kpop
# hahahahahahahahayu : hahahahahahahahayu
# txt : txt
# tungguin : tungguin
# internet : internet
# memudahkan : mudah
# menakutkan : takut
# ditakuti : takut
# ditakuttakuti : ditakuttakuti
# mikirin : mikirin
# hidup : hidup
# untungnya : untung
# didesa : desa
# ibarat : ibarat
# uang : uang
# metik : metik
# daun : daun
# singkong : singkong
# pepaya : pepaya
# dijadiin : dijadiin
# sayur : sayur
# apaapanya : apaapanya
# ngekritik : ngekritik
# saiki : saiki
# stelah : stelah
# banyakny : banyakny
# disparitas : disparitas
# tntang : tntang
# pmbahasan : pmbahasan
# akhirnya : akhir
# tulisan : tulis
# cukup : cukup
# mencerahkan : cerah
# respect : respect
# pak : pak
# chatib : chatib
# lumayan : lumayan
# nenangin : nenangin
# keperosok : perosok
# ngerasa : ngerasa
# much : much
# better : better
# kabar : kabar
# ditarik : tarik
# ulur : ulur
# harapan : harap
# roda : roda
# berjalan : jalan
# idol : idol
# lagi : lagi
# aslmlkm : aslmlkm
# kabareu : kabareu
# cinta : cinta
# kaliyan : kaliyan
# aya : aya
# naon : naon
# kituu : kituu
# kudu : kudu
# rada : rada
# save : save
# money : money
# iyeu : iyeu
# stopbalanja : stopbalanja
# menghantui : hantu
# dit : dit
# heran : heran
# bapaknya : bapak
# senang : senang
# lihat : lihat
# selamat : selamat
# dendam : dendam
# apalah : apa
# jumpa : jumpa
# cium : cium
# tangannya : tangan
# nahan : nahan
# sepatu : sepatu
# sarrr : sarrr
# sarr : sarr
# cuan : cuan
# start : start
# now : now
# nanti : nanti
# pastinya : pasti
# masa : masa
# gampang : gampang
# banget : banget
# rumah : rumah
# noh : noh
# moga : moga
# duit : duit
# butuh : butuh
# bet : bet
# alias : alias
# kurangin : rangin
# party : party
# goblookk : goblookk
# nonton : nonton
# ngeluarin : ngeluarin
# penting : penting
# ketinggalan : tinggal
# budidaya : budidaya
# maggot : maggot
# seksi : seksi
# pandemi : pandemi
# tindakan : tindak
# menambahkan : tambah
# penghasilan : hasil
# bersemangat : semangat
# mencari : cari
# tambahan : tambah
# fess : fess
# kalian : kalian
# lanjut : lanjut
# sayang : sayang
# tabungannya : tabung
# inves : inves
# kokk : kokk
# semengerikan : keri
# nah : nah
# kek : kek
# momok : momok
# pastiin : pastiin
# memastikan : pasti
# deket : deket
# kuartalnya : kuartal
# mikirnya : mikirnya
# balikannya : balik
# terlalu : terlalu
# keras : keras
# kerasin : kerasin
# perkara : perkara
# istilahnya : istilah
# parah : parah
# dilewatin : dilewatin
# kok : kok
# bagian : bagi
# jeleknya : jelek
# tinggi : tinggi
# china : china
# sri : sri
# mulyani : mulyani
# mempertahankan : tahan
# alasan : alas
# menetap : tetap
# sini : sini
# cost : cost
# nabungnya : nabungnya
# bentar : bentar
# expect : expect
# ketemu : ketemu
# kenyataannya : nyata
# kagak : kagak
# biaya : biaya
# perawatan : awat
# gigi : gigi
# mahal : mahal
# mereka : mereka
# xxx : xxx
# iku : iku
# tulisane : tulisane
# besaran : besar
# geng : geng
# udu : udu
# ngapa : ngapa
# mutu : mutu
# diangkat : angkat
# besok : besok
# woy : woy
# khawatir : khawatir
# blom : blom
# apaa : apaa
# id : id
# maaf : maaf
# sis : sis
# bro : bro
# toleransi : toleransi
# ttng : ttng
# pasca : pasca
# stabilitas : stabilitas
# politik : politik
# godaan : goda
# pengeluaran : keluar
# ditengah : tengah
# badai : badai
# solo : solo
# siapa : siapa
# bilang : bilang
# cant : cant
# buy : buy
# us : us
# happiness : happiness
# hahahah : hahahah
# aslii : asli
# kapan : kapan
# diesel : diesel
# menunjukkan : tunjuk
# tanda : tanda
# kekacauandan : kekacauandan
# merusak : rusak
# serangan : serang
# tekanan : tekan
# terbebas : bebas
# oil : oil
# gas : gas
# terselamatkan : selamat
# coal : coal
# tdk : tdk
# energy : energy
# bisniskerjakulia : bisniskerjakulia
# bleu : bleu
# treasure : treasure
# datang : datang
# soon : soon
# yaa : yaa
# anjirrrr : anjirrrr
# gembor : gembor
# sebar : sebar
# ketakutan : takut
# warning : warning
# seakan : akan
# perusaahaan : perusaahaan
# lay : lay
# off : off
# karyawan : karyawan
# collapse : collapse
# fuck : fuck
# kayak : kayak
# jangankan : jangan
# warga : warga
# tuhan : tuhan
# sekalipun : sekalipun
# vid : vid
# lewat : lewat
# ngonser : ngonser
# brarti : brarti
# something : something
# luar : luar
# kmren : kmren
# donk : donk
# clara : clara
# wkwkwkwkwk : wkwkwkwkwk
# is : is
# life : life
# ygy : ygy
# hura : hura
# meski : meski
# terpaan : terpa
# menghembus : hembus
# dulunya : dulunya
# bakalan : bakal
# tambah : tambah
# belum : belum
# menyerah : serah
# dijual : jual
# fnfjb : fnfjb
# belakangan : belakang
# muncul : muncul
# usai : usai
# sejumlah : jumlah
# lembaga : lembaga
# internasional : internasional
# para : para
# pejabat : jabat
# menyebutkannya : sebut
# wkwkwkwwk : wkwkwkwwk
# kaka : kaka
# w : w
# anjrt : anjrt
# emak : emak
# cemas : cemas
# kecewa : kecewa
# ama : ama
# btw : btw
# ni : ni
# teringat : ingat
# video : video
# melempari : lempari
# karya : karya
# beliau : beliau
# sunflower : sunflower
# sup : sup
# tomat : tomat
# kaleng : kaleng
# protes : protes
# lukisan : lukis
# berharga : harga
# kemanusiaan : manusia
# naurr : naurr
# dibandingkan : banding
# kenaikan : naik
# bbm : bbm
# ku : ku
# hadpi : hadpi
# asma : asma
# kalimat : kalimat
# pertama : pertama
# wkwkwwk : wkwkwwk
# dampaknya : dampak
# krna : krna
# belom : bom
# melek : melek
# entah : entah
# ngeri : ngeri
# sedep : sedep
# semakin : makin
# waspada : waspada
# situasi : situasi
# menentu : tentu
# masih : masih
# ngandelin : ngandelin
# mbakmbak : mbakmbak
# itzy : itzy
# twicetolong : twicetolong
# gapeduli : gapeduli
# ticketing : ticketing
# bntr : bntr
# gw : gw
# jual : jual
# ginjal : ginjal
# gaboong : gaboong
# kandakanda : kandakanda
# jenius : jenius
# penguasa : kuasa
# twitter : twitter
# kemungkinan : mungkin
# tau : tau
# arti : arti
# tadi : tadi
# sore : sore
# ampun : ampun
# astagaa : astagaa
# nderr : nderr
# malem : malem
# ngakakk : ngakakk
# dilakukan : laku
# cutlost : cutlost
# kbtuhan : kbtuhan
# sekunder : sekunder
# tersiser : tersiser
# siapin : siapin
# bercocok : cocok
# tanam : tanam
# pelihara : pelihara
# ikan : ikan
# lele : lele
# nila : nila
# panel : panel
# surya : surya
# ide : ide
# out : out
# of : of
# box : box
# langgar : langgar
# barangkali : barangkali
# capek : capek
# secapek : capek
# skrang : skrang
# karna : karna
# rezeki : rezeki
# kebergantungan : gantung
# jaman : jaman
# skrng : skrng
# nurut : nurut
# mjb : mjb
# tips : tips
# ngebatin : ngebatin
# perasaan : asa
# kehidupanku : hidup
# sesederhana : sederhana
# wakanda : wakanda
# wani : wani
# perih : perih
# sepeleee : sepeleee
# hawar : hawar
# na : na
# hareup : hareup
# karasana : karasana
# geus : geus
# ti : ti
# ayeuna : ayeuna
# keneh : keneh
# eropa : eropa
# jatuh : jatuh
# jurang : jurang
# bnran : bnran
# menabung : tabung
# woi : woi
# ingat : ingat
# rumor : rumor
# idolku : idolku
# mempersiapkan : siap
# sedangkan : sedang
# kedatangan : datang
# ditanamkan : tanam
# bontot : bontot
# selalu : selalu
# gedung : gedung
# mata : mata
# sawah : sawah
# abis : abis
# kejual : jual
# bergelimang : gelimang
# harta : harta
# nasibnasib : nasibnasib
# pepi : pepi
# seketika : ketika
# ikutan : ikut
# mengurangi : kurang
# porsi : porsi
# sedihhhhh : sedihhhhh
# pengen : ken
# tuapuk : tuapuk
# lambene… : lambene
# anjjj : anjjj
# ayoo : ayoo
# semangat : semangat
# ah : ah
# gajian : gaji
# hidupku : hidup
# berkalikali : berkalikali
# namanya : nama
# kerasa : rasa
# kakek : kakek
# mu : mu
# kamu : kamu
# nyananti : nyananti
# anakmu : anak
# usah : usah
# let : let
# flows : flows
# nothing : nothing
# to : to
# worry : worry
# my : my
# men : men
# anjrit : anjrit
# ambang : ambang
# ketidakwarasan : ketidakwarasan
# wacana : wacana
# risih : risih
# kmaren : kmaren
# nntn : nntn
# vt : vt
# dibahas : bahas
# terdampak : dampak
# gabakal : gabakal
# separah : parah
# macam : macam
# jerman : jerman
# dkk : dkk
# pelaku : laku
# kebingungan : bingung
# tersendiri : sendiri
# sisi : sisi
# profit : profit
# rasa : rasa
# ngingetin : ngingetin
# berhemat : hemat
# wkwkwkw : wkwkwkw
# sist : sist
# bangetttt : bangetttt
# padhaal : padhaal
# stres : stres
# jajan : jajan
# albummm : albummm
# huuhuhuhuhu : huuhuhuhuhu
# stuju : stuju
# perputaran : putar
# skrg : skrg
# mnurun : mnurun
# awalnya : awal
# seluruh : seluruh
# aq : aq
# buka : buka
# tw : tw
# krja : krja
# senin : senin
# ampe : ampe
# jum : jum
# rmh : rmh
# nyambi : nyambi
# online : online
# update : update
# corona : corona
# akut : akut
# multitasking : multitasking
# iphone : iphone
# eh : eh
# wkwkwkwk : wkwkwkwk
# berulang : ulang
# sekali : sekali
# jokowi : jokowi
# aduh : aduh
# ancur : ancur
# mina : mina
# tai : tai
# naikkin : naikkin
# suku : suku
# bunga : bunga
# musti : musti
# cepet : cepet
# bayar : bayar
# hutang : hutang
# kurangi : kurang
# impor : impor
# bentuk : bentuk
# dolar : dolar
# makasi : makas
# sudah : sudah
# positif : positif
# thinking : thinking
# walaupun : walaupun
# termasuk : masuk
# penipuan : tipu
# kebal : kebal
# sempat : sempat
# bersiap : siap
# keseret : seret
# belanja : belanja
# ditabung : tabung
# konsepnya : konsep
# kemarin : kemarin
# panick : panick
# buying : buying
# ikut : ikut
# melonjak : lonjak
# pe : pe
# dicari : cari
# nyarinya : nyarinya
# gausah : gausah
# indon : indon
# gakena : gakena
# zelensky : zelensky
# goblok : goblok
# nyeret : nyeret
# rakyatnya : rakyat
# inyernasional : inyernasional
# alami : alami
# makanya : makanya
# pinter : pinter
# populer : populer
# buta : buta
# askrl : askrl
# masifnya : masif
# fearmongering : fearmongering
# bukannya : bukan
# terhambat : hambat
# memicu : picu
# resesinya : resesi
# cmiiw : cmiiw
# kekayaannya : kaya
# kembalikan : kembali
# hwakakak : hwakakak
# 🇺🇸 :
# as : as
# smakin : smakin
# kuat : kuat
# sebuah : buah
# cuitan : cuit
# kumandangkan : kumandang
# dialihkan : alih
# rd : rd
# total : total
# sisihkan : sisih
# ditaruh : taruh
# tapi : tapi
# memang : memang
# sedia : sedia
# darurat : darurat
# target : target
# muda : muda
# g : g
# slh : slh
# zi : zi
# festival : festival
# boros : boros
# tidak : tidak
# adik : adik
# related : related
# bilek : bilek
# dikhawatirin : dikhawatirin
# menghawatirkan : menghawatirkan
# orangorang : orangorang
# alam : alam
# qq : qq
# resmi : resmi
# bris : bris
# naik : naik
# x : x
# lipat : lipat
# dia : dia
# mksd : mksd
# kaum : kaum
# naga : naga
# langit : langit
# jdi : jdi
# kiamat : kiamat
# seharihari : seharihari
# paspasan : paspasan
# nunggunya : nunggunya
# ngobrol : ngobrol
# frekuensi : frekuensi
# kasus : kasus
# seru : seru
# anget : anget
# reksadana : reksadana
# ka : ka
# mak : mak
# blgin : blgin
# responnya : responnya
# la : la
# malas : malas
# tanya : tanya
# mengenai : kena
# sering : sering
# fyp : fyp
# tiktoknya : tiktoknya
# kemudian : kemudian
# jawab : jawab
# jelaskan : jelas
# gdp : gdp
# tetek : tetek
# bengek : bengek
# sejauh : jauh
# pengetahuanku : tahu
# cetek : cetek
# maximum : maximum
# dimanamana : dimanamana
# hancur : hancur
# dsbnya : dsbnya
# sangat : sangat
# optimis : optimis
# contrarian : contrarian
# mmg : mmg
# gt : gt
# tentu : tentu
# bskk : bskk
# ngr : ngr
# swt : swt
# pilih : pilih
# infestasi : infestasi
# cicilan : cicil
# sofa : sofa
# dispenser : dispenser
# hp : hp
# minta : minta
# motor : motor
# allah : allah
# lncr : lncr
# trs : trs
# rasanya : rasa
# terbalik : balik
# ° :
# singkat : singkat
# ataupun : atau
# kedampak : dampak
# amankeun : amankeun
# ribut : ribut
# pencipta : cipta
# semesta : semesta
# a : a
# sana : sana
# kehendak : hendak
# — :
# kdi : kdi
# non : non
# dibilang : bilang
# pailit : pailit
# sehingga : sehingga
# permintaan : minta
# menyebutkan : sebut
# diperkuat : kuat
# rakyat : rakyat
# ubet : ubet
# ulet : ulet
# campur : campur
# cengengesan : cengengesan
# kenal : kenal
# fafifu : fafifu
# sesuk : sesuk
# gasss : gasss
# maneh : maneh
# tangi : tang
# isuk : isuk
# perlambatan : lambat
# bisaa : bisaa
# nikah : nikah
# bawa : bawa
# bahagia : bahagia
# keluarga : keluarga
# sii : sii
# persalinan : salin
# etapi : etapi
# pacar : pacar
# jgn : jgn
# lengkapcepatberitanya : lengkapcepatberitanya
# beritaterkini : beritaterkini
# keinget : keinget
# kemaren : kemaren
# purchase : purchase
# barang : barang
# menyesal : sesal
# srsly : srsly
# beberapa : beberapa
# lg : lg
# well : well
# berbasis : bas
# data : data
# fakta : fakta
# kira : kira
# langkah : langkah
# diambil : ambil
# kl : kl
# amati : amat
# kebijakan : bijak
# atasnya : atas
# bawahannya : bawah
# niat : niat
# hati : hati
# blackpink : blackpink
# in : in
# your : your
# area : area
# kirim : kirim
# postingan : postingan
# digrup : grup
# kantor : kantor
# pantesan : pantesan
# ternyata : nyata
# nyiahahaha : nyiahahaha
# coret : coret
# wl : wl
# kebeli : kebel
# dah : dah
# jobless : jobless
# aigooo : aigooo
# budaq : budaq
# corporate : corporate
# ges : ges
# kabarnya : kabar
# mencuat : cuat
# sumbernya : sumber
# hihi : hihi
# tautau : tautau
# gaji : gaji
# bey : bey
# sisa : sisa
# utang : utang
# brp : brp
# dmn : dmn
# ngekos : ngekos
# sekalian : sekali
# laundry : laundry
# kosan : kosan
# laundrydisediain : laundrydisediain
# mesin : mesin
# cuci : cuci
# jt : jt
# kebanyakan : banyak
# selfreward : selfreward
# ush : ush
# diadain : diadain
# dicut : cut
# taruh : taruh
# dana : dana
# inget : inget
# masal : masal
# klo : klo
# spa : spa
# reseeeeeeeeeee : reseeeeeeeeeee
# ngerti : ngerti
# kakak : kakak
# keponakan : keponakan
# ilangin : ilangin
# tanggung : tanggung
# ngasi : ngasi
# irit : irit
# skincare : skincare
# toiletris : toiletris
# cut : cut
# biasanya : biasa
# terjun : terjun
# bukannye : bukannye
# stang : stang
# aje : aje
# duh : duh
# ente : ente
# strgr : strgr
# nyuruh : nyuruh
# tujuan : tuju
# ngambil : ngambil
# kemaerin : kemaerin
# wong : wong
# yok : yok
# monggo : monggo
# tarik : tarik
# high : high
# risk : risk
# tuker : tuker
# small : small
# perbanyak : banyak
# iso : iso
# resesa : resesa
# ubah : ubah
# rejeki : rejeki
# strategi : strategi
# antisipasi : antisipasi
# sihdari : sihdari
# duitnyabudah : duitnyabudah
# deng : deng
# yaahh : yaahh
# wakakkaka : wakakkaka
# harusnya : harus
# ganti : ganti
# krismon : krismon
# relevan : relevan
# dsono : dsono
# napa : napa
# massal : massal
# alangkah : alangkah
# baiknya : baik
# dipersiapkan : siap
# miskin : miskin
# sekarangpun : sekarang
# smpt : smpt
# brpkr : brpkr
# sii… : sii
# takutt : takutt
# akhr : akhr
# konsumsi : konsumsi
# bukannkah : bukannkah
# down : down
# sdgkn : sdgkn
# nyelamatin : nyelamatin
# mkr : mkr
# dtakuti : dtakuti
# merka : merka
# rnckn : rnckn
# kebaca : baca
# sendernya : sender
# typo : typo
# ngetik : ngetik
# need : need
# any : any
# reassurance : reassurance
# for : for
# upcoming : upcoming
# recession : recession
# then : then
# there : there
# go : go
# sosoan : sosoan
# dahal : dahal
# sebelum : belum
# kaga : kaga
# skshshshshshhs : skshshshshshhs
# brojol : brojol
# dapetin : dapetin
# tua : tua
# sepakat : sepakat
# berkebun : kebun
# company : company
# jara : jara
# dspet : dspet
# offering : offering
# letter : letter
# ikuti : ikut
# ajakan : aja
# adian : adi
# napitulu : napitulu
# demi : demi
# kemajuan : maju
# sebenarnya : benar
# dikhawatirkan : khawatir
# efeknya : efek
# pengangguran : anggur
# kelaparan : lapar
# kriminalitas : kriminalitas
# msk : msk
# harap : harap
# kesitu : kesitu
# diingat : ingat
# menyelesaikan : selesai
# don : don
# splurge : splurge
# be : be
# wise : wise
# furthermore : furthermore
# terintegrasi : integrasi
# melambat : lambat
# basri : basri
# panic : panic
# lagian : lagi
# santai : santai
# taunya : tau
# dikasih : kasih
# sebulan : bulan
# venue : venue
# dikira : kira
# stay : stay
# sultan : sultan
# dimajuin : dimajuin
# lol : lol
# sender : sender
# dikamar : kamar
# ngomongin : ngomongin
# ngaruh : ngaruh
# kecuali : kecuali
# pekerja : kerja
# buruh : buruh
# nderrr : nderrr
# weh : weh
# elahhh : elahhh
# gess : gess
# pls : pls
# salty : salty
# sihngapain : sihngapain
# planin : planin
# desember : desember
# bngung : bngung
# knp : knp
# lumpuhnya : lumpuh
# brrarti : brrarti
# mengendalikan : kendali
# smg : smg
# benerannn : benerannn
# seharian : hari
# kau : kau
# besarbesaran : besarbesaran
# woii : woii
# oi : oi
# bngke : bngke
# gaada : gaada
# manusia : manusia
# memprediksi : prediksi
# diatas : atas
# ingpo : ingpo
# dong : dong
# yaallah : yaallah
# ️️ :
# sebenernya : sebenernya
# sblm : sblm
# tgl : tgl
# kembar : kembar
# diskon : diskon
# bertebaran : tebar
# impulsif : impulsif
# ak : ak
# mw : mw
# bli : bli
# org² : org
# bi : bi
# layk : layk
# fxck : fxck
# bertransaksi : transaksi
# barter : barter
# baik : baik
# dosen : dosen
# itb : itb
# gembira : gembira
# sakjane : sakjane
# tuku : tuku
# omah : omah
# worth : worth
# nek : nek
# tepak : tepak
# merosot : merosot
# kuhanya : hanya
# era : era
# lockdown : lockdown
# sanggup : sanggup
# harus : harus
# peduli : peduli
# nyimpen : nyimpen
# mna : mna
# elodie : elodie
# ngurusin : ngurusin
# fafifuuuu : fafifuuuu
# maunya : mau
# with : with
# youu : youu
# dilanda : landa
# mmi : mmi
# tbh : tbh
# diniatin : diniatin
# management : management
# lancar : lancar
# kedepannya : depan
# akhir² : akhir
# demo : demo
# museum : museum
# aktivis : aktivis
# jso : jso
# londons : londons
# national : national
# gallery : gallery
# sasaran : sasar
# van : van
# gogh : gogh
# tuntutan : tuntut
# tentang : tentang
# dimana² : mana
# netizen : netizen
# leslar : leslar
# itam : itam
# koyo : koyo
# ngene : ngene
# meh : meh
# dikon : dikon
# tuk : tuk
# siap² : siap
# dihadang : dihadang
# ombak : ombak
# auto : auto
# panggil : panggil
# istana : istana
# ngendaliin : ngendaliin
# seneng : neng
# rupiah : rupiah
# melemah : lemah
# janji : janji
# rebu : rebu
# rebo : rebo
# beruntunglah : untung
# daerah : daerah
# argentina : argentina
# transaksi : transaksi
# km : km
# check : check
# brush : brush
# real : real
# techniques : techniques
# dibanding : banding
# perbedaan : beda
# terletak : letak
# keparahannya : parah
# panjang : panjang
# utas : utas
# disiapkan : siap
# disebabkan : sebab
# mrosotnya : mrosotnya
# melemahnya : lemah
# adidaya : adidaya
# serikat : serikat
# jare : jare
# ojo : ojo
# males : males
# iki : iki
# gasspoll : gasspoll
# rt : rt
# ngepajakin : ngepajakin
# perak : perak
# foto : foto
# peace : peace
# sign : sign
# gajadi : gajadi
# malming : malming
# pngn : pngn
# santaiampga : santaiampga
# nambah : nambah
# pikiranapa : pikiranapa
# diajak : ajak
# ghibahin : ghibahin
# genk : genk
# kantin : kantin
# mataramsdh : mataramsdh
# kuduga : duga
# ghibah : ghibah
# inipasti : inipasti
# overthinkinglah : overthinkinglah
# kagakyg : kagakyg
# dighibahin : dighibahin
# resesiampprediksi : resesiampprediksi
# pan : pan
# yakkagak : yakkagak
# otak : otak
# inimakin : inimakin
# oleng : oleng
# jadinya : jadi
# menyambut : sambut
# pildun : pildun
# grup : grup
# menolak : tolak
# diambang : ambang
# r : r
# only : only
# one : one
# beda : beda
# wabah : wabah
# riil : riil
# ukm : ukm
# ditambah : tambah
# ol : ol
# shop : shop
# ojol : ojol
# sgt : sgt
# begini : begini
# nasihat : nasihat
# raditya : raditya
# dika : dika
# tanggapi : tanggap
# fokus : fokus
# tertunda : tunda
# since : since
# running : running
# smoothly : smoothly
# dicharge : dicharge
# battrey : battrey
# health : health
# nangis : nang
# liatnya : liat
# menyepelekan : sepele
# bisnisnya : bisnis
# finansial : finansial
# contohnya : contoh
# negara² : negara
# ngelempar : ngelempar
# nempelin : nempelin
# tembok : tembok
# lem : lem
# orasi : orasi
# ny : ny
# tentag : tentag
# london : london
# pc : pc
# belajar : ajar
# basic : basic
# skill : skill
# masak : masak
# api : api
# pertukangan : tukang
# meramu : ramu
# berburu : buru
# kayaknya : kayak
# berguna : guna
# lima : lima
# mendatang : datang
# daripada : daripada
# suerrr : suerrr
# meeting : meeting
# kantorpasti : kantorpasti
# terosssss : terosssss
# tiktok : tiktok
# isinya : isi
# manajmn : manajmn
# waswas : waswas
# kluarin : kluarin
# duid : duid
# ayank : ayank
# kelam : kelam
# menimpa : timpa
# ending : ending
# kisah : kisah
# kirakira : kirakira
# lovestory : lovestory
# masi : mas
# berarti : arti
# mengencangkan : encang
# ikat : ikat
# seokjin : seokjin
# meninggal : tinggal
# dibesarbesarin : dibesarbesarin
# jg : jg
# hilang : hilang
# diatur : atur
# liberalism : liberalism
# iman : iman
# mengatur : atur
# berdoa : doa
# lebay : lebay
# cuap : cuap
# cuapnya : cuapnya
# kapanpun : kapan
# tenang : tenang
# iyakah : iya
# emas : emas
# anjloknya : anjlok
# kirain : kirain
# sy : sy
# belio : belio
# dnger : dnger
# nih : nih
# ngikutin : ngikutin
# ramalan : ramal
# yutub : yutub
# meanwhile : meanwhile
# hallo : hallo
# kabareuuu : kabareuuu
# terimakashhhhh : terimakashhhhh
# kpopers : kpopers
# dilema : dilema
# korban : korban
# sekecil : kecil
# berkelahi : kelah
# simulasi : simulasi
# tad : tad
# teh : teh
# segelap : gelap
# keuangan : uang
# huhu : huhu
# direkrut : rekrut
# bu : bu
# berlindung : lindung
# adalah : adalah
# hamba : hamba
# maha : maha
# peting : peting
# badan : badan
# gerak : gerak
# jemput : jemput
# dinegara : negara
# weverse : weverse
# rasany : rasany
# checkout : checkout
# semuany… : semuany
# darlene : darlene
# membisukan : bisu
# dini : dini
# simpen : simpen
# duitnya : duit
# jaga : jaga
# iyaaaa : iyaaaa
# huff : huff
# tercipta : cipta
# akuuu : akuuu
# yaaaaaaaaaa : yaaaaaaaaaa
# walopun : walopun
# rumornya : rumor
# semenakutkan : takut
# nnton : nnton
# bagibagi : bagibagi
# cairin : cairin
# ranah : ranah
# disiapin : disiapin
# mental : mental
# doa : doa
# bandel : bandel
# nyerah : nyerah
# wow : wow
# quarter : quarter
# crisis : crisis
# anjir… : anjir
# uda : uda
# disuruh : suruh
# tabung : tabung
# gabole : gabole
# keluarin : keluarin
# penting… : penting
# seserius : serius
# itu… : itu
# goodbye : goodbye
# mevah : mevah
# yagesya : yagesya
# momogi : momogi
# harganya : harga
# ukurannya : ukur
# perayaan : raya
# blok : blok
# heboh : heboh
# risiko : risiko
# kebiasaan : biasa
# lu : lu
# paylater : paylater
# pacaran : pacar
# ratu : ratu
# tisha : tisha
# gus : gus
# muhaimin : muhaimin
# troye : troye
# sivan : sivan
# molen : molen
# presidenjokowihebat : presidenjokowihebat
# ma : ma
# city : city
# oktober : oktober
# jinnie : jinnie
# album : album
# njuk : njuk
# piyeee : piyeee
# kreditan : kredit
# konon : konon
# kelihatan : lihat
# terdampaknya : dampak
# tunggakan : tunggak
# aktifin : aktifin
# aneka : aneka
# istilah : istilah
# pertumbuhan : tumbuh
# ngak : ngak
# anta : anta
# anti : anti
# antuma : antuma
# aj : aj
# wkwkwkwkwkkwkwkwkwkwkw : wkwkwkwkwkkwkwkwkwkwkw
# nakutnakutin : nakutnakutin
# asuransi : asuransi
# diakhir : akhir
# anjinggggg : anjinggggg
# ngalami : ngalami
# gempa : gempa
# tsunami : tsunami
# likuifaksi : likuifaksi
# bangkit : bangkit
# apanya : apa
# viviz : viviz
# anjir : anjir
# perketat : ketat
# gamau : gamau
# stress : stress
# terburuknya : buruk
# dimasa : masa
# nyari : nyari
# gila : gila
# join : join
# me : me
# memperkuat : kuat
# ketimbang : ketimbang
# oooh : oooh
# bisaaa : bisaaa
# nct : nct
# dream : dream
# yaps : yaps
# sekolah : sekolah
# aslinya : asli
# mengumpulkan : kumpul
# bekal : bekal
# anjiing : anjiing
# tunggu : tunggu
# kepastian : pasti
# dl : dl
# seruuu : seruuu
# tadinya : tadi
# dijelasin : dijelasin
# bersamamu : sama
# knt : knt
# worst : worst
# casenya : casenya
# gbsa : gbsa
# bp : bp
# also : also
# anjrot : anjrot
# hrs : hrs
# fakk : fakk
# atur : atur
# arus : arus
# kas : kas
# gmw : gmw
# dluan : dluan
# taddd : taddd
# pribadi : pribadi
# dimulai : mulai
# olshop : olshop
# open : open
# po : po
# face : face
# sun : sun
# berlanjut : lanjut
# announcement : announcement
# additional : additional
# tour : tour
# dates : dates
# rekeningku : rekening
# bersama : sama
# jaya : jaya
# keuanganku : uang
# inggat : inggat
# trial : trial
# meroket : roket
# mengerikan : keri
# dikabarkan : kabar
# fansnya : fansnya
# penggalangan : galang
# fansny : fansny
# remember : remember
# next : next
# year : year
# not : not
# joke : joke
# disana : sana
# impactnya : impactnya
# akang : akang
# jekkk : jekkk
# jee : jee
# dijalani : jalan
# sepanjang : panjang
# memunculkan : muncul
# peluang : peluang
# sepemikiran : pikir
# rata : rata
# berduit : duit
# de : de
# cek : cek
# youtub : youtub
# mewah : mewah
# dasarnya : dasar
# hahaha : hahaha
# sdh : sdh
# terbiasa : biasa
# bs : bs
# hadapai : hadapai
# pemasukan : pasu
# serbah : serbah
# bernafas : nafas
# semangatt : semangatt
# oraa : oraa
# kismin : kismin
# tetepi : tetepi
# memahami : paham
# wedi : wedi
# resesiteko : resesiteko
# kabeh : kabeh
# syukuri : syukur
# lan : lan
# nikmatidalane : nikmatidalane
# gusti : gusti
# peteng : teng
# murah : murah
# nyoret : nyoret
# kuota : kuota
# pupita : pupita
# resesi… : resesi
# kipop : kipop
# titit : titit
# menurutku : turut
# dateng : dateng
# investasinya : investasi
# rill : rill
# jualnya : jual
# liquid : liquid
# beban : beban
# gosip : gosip
# mantau : mantau
# apapn : apapn
# trending : trending
# fypku : fypku
# idupnya : idupnya
# engapan : engapan
# takutin : takutin
# jek : jek
# polisi : polisi
# odgj : odgj
# berantakan : beranta
# akui : aku
# pimpin : pimpin
# panglima : panglima
# apapun : apa
# perut : perut
# pendidikan : didik
# amankan : aman
# kebutuhan : butuh
# cukupi : cukup
# ayah : ayah
# kini : kini
# terseok : seok
# seok : seok
# boros² : boros
# menyikapi : sikap
# serem : rem
# kwkwkwk : kwkwkwk
# merem : merem
# ina : ina
# kembredek : kembredek
# ngerem : ngerem
# kpr : kpr
# kredit : kredit
# mbl : mbl
# sifatnya : sifat
# produktif : produktif
# bkn : bkn
# konsumtif : konsumtif
# karn : karn
# bekerja : kerja
# wahhh : wahhh
# seminimal : minimal
# eratkan : erat
# sabuk : sabuk
# yak : yak
# gituan : gituan
# bedakan : beda
# keinginan : ingin
# hmm : hmm
# sepertinya : seperti
# ok : ok
# sehati : sehat
# pen : pen
# brondong : brondong
# saya : saya
# premipass : premipass
# proseka : proseka
# ‘ :
# diramal : ramal
# lolos : lolos
# bandunia : bandunia
# sahabat : sahabat
# transformasi : transformasi
# pemulung : pulung
# bantar : bantar
# gebang : gebang
# silahkan : silah
# bincang : bincang
# dukung : dukung
# misi : misi
# dgn : dgn
# subscribe : subscribe
# like : like
# share : share
# gratis : gratis
# pertengahan : tengah
# aset : aset
# piring : piring
# takutnya : takut
# plus : plus
# maksudnya : maksud
# ekspornya : ekspor
# ekspor : ekspor
# tutup : tutup
# buku : buku
# ul : ul
# jun : jun
# white : white
# stat : stat
# gwmasa : gwmasa
# cowo : cowo
# berdatangan : datang
# menonton : tonton
# konser‍️ : konser
# berkoar : koar
# nggawe : nggawe
# putek : putek
# sejak : sejak
# tiada : tiada
# iyakan : iya
# joo : joo
# tonton : tonton
# future : future
# ngelangkah : ngelangkah
# memperbaiki : baik
# semuanya : semua
# humphhh… : humphhh
# adaada : adaada
# cobaan : coba
# generasi : generasi
# an : an
# konsumennya : konsumen
# jualin : jualin
# mba : mba
# ancer : ancer
# yahhh : yahhh
# dhe : dhe
# macem : macem
# developer : developer
# semudah : mudah
# nurunin : nurunin
# paaak : paaak
# saranin : saranin
# financially : financially
# stable : stable
# terusterusan : terusterusan
# blue : blue
# aamiin : aamiin
# sami : sami
# bageur : bageur
# healthy : healthy
# and : and
# safe : safe
# menjelang : jelang
# berak : berak
# kaki : kaki
# malam : malam
# abang : abang
# wara : wara
# wiri : wiri
# tukang : tukang
# asongan : asong
# warung : warung
# pecel : pecel
# tenda : tenda
# penjelasan : jelas
# sederhana : sederhana
# stagflasi : stagflasi
# lain : lain
# expectation : expectation
# memburuk : buruk
# reality : reality
# lany : lany
# soundrenaline : soundrenaline
# djakarta : djakarta
# warehouse : warehouse
# project : project
# pernikahan : nikah
# mantappp : mantappp
# cemilan : cemilan
# kriuk : kriuk
# dom : dom
# pekalongan : kalong
# joko : joko
# widodo : widodo
# menyatakan : nyata
# hingga : hingga
# energi : energi
# kementerianlembaga : kementerianlembaga
# kementerian : menteri
# sampo : sampo
# habis : habis
# air : air
# nggausah : nggausah
# bimbang : bimbang
# balik : balik
# bets : bets
# september : september
# keliatan : liat
# soundcheck : soundcheck
# yha : yha
# ngalamin : ngalamin
# bertahuntahun : bertahuntahun
# hahahahah : hahahahah
# benerrrr : benerrrr
# media : media
# gembor² : gembor
# kreator : kreator
# modelnya : model
# tujuanya : tujuanya
# pendapat : dapat
# dilempar : lempar
# soup : soup
# vangogh : vangogh
# seni : seni
# activists : activists
# gombal : gombal
# kasi : kasi
# ribu : ribu
# kmu : kmu
# batangan : batang
# maksud : maksud
# pelit : pelit
# kakakmu : kakak
# sihh : sihh
# sepengalamanku : alam
# lalu : lalu
# tul : tul
# tat : tat
# ttp : ttp
# pun : pun
# dgr : dgr
# keputusan : putus
# jalanin : jalanin
# nolong : nolong
# melihat : lihat
# pulih : pulih
# gambaran : gambar
# menkominfo : menkominfo
# menginstruksikan : instruksi
# sivitas : sivitas
# berkolaborasi : kolaborasi
# mempercepat : cepat
# realisasi : realisasi
# anggaran : anggar
# fresh : fresh
# graduate : graduate
# makasih : makasih
# mativatorku : mativatorku
# reksa : reksa
# memilih : pilih
# chip : chip
# mayan : mayan
# apabila : apabila
# memiliki : milik
# pihak : pihak
# proses : proses
# pengembangan : kembang
# usaha : usaha
# meghadapi : meghadapi
# headline : headline
# seumur : umur
# hari² : hari
# nya : nya
# nak : nak
# terkejod : terkejod
# melarat : melarat
# numpang : numpang
# kejar : kejar
# setoran : setor
# iyyaaa : iyyaaa
# mslah : mslah
# mlah : mlah
# kumau : mau
# orang² : orang
# hebat : hebat
# tersebut : sebut
# sya : sya
# nganggur : nganggur
# kerjaan : kerja
# berapa : berapa
# menolong : tolong
# gelp : gelp
# tap : tap
# lix : lix
# ht : ht
# parasit : parasit
# boss : boss
# inggrismu : inggris
# diganti : ganti
# charles : charles
# by : by
# way : way
# gusur : gusur
# pelix : pelix
# segera : segera
# dirikan : diri
# khilafuck : khilafuck
# inggris : inggris
# raya : raya
# terkesan : kes
# muslim : muslim
# gimanapun : gimanapun
# hadapain : hadapain
# sambil : sambil
# ngeluh : ngeluh
# sesekali : sekal
# kuartal : kuartal
# iii : iii
# tumbuh : tumbuh
# jokowihebat : jokowihebat
# berlaku : laku
# stan : stan
# resresan : resresan
# peyek : peyek
# enakan : enak
# billar : billar
# streeeesss : streeeesss
# abstrak : abstrak
# nulis : nulis
# digit : digit
# ovt : ovt
# cok : cok
# onok : onok
# e : e
# dahulu : dahulu
# dis : dis
# ngmgin : ngmgin
# ‍‍ :
# anjg : anjg
# masalhnya : masalhnya
# mengkis² : mengkis
# wrerwrerr : wrerwrerr
# bersifat : sifat
# menggiring : giring
# opini : opini
# institusi : institusi
# dibawah : bawah
# rally : rally
# trust : trust
# overstay : overstay
# titik : titik
# susahnya : susah
# bnyak : bnyak
# dlm : dlm
# stop : stop
# malmingan : malmingan
# bodoamat : bodoamat
# all : all
# want : want
# her : her
# boro : boro
# jelasin : jelasin
# biasanyakan : biasanyakan
# bahasanya : bahasa
# bilangin : bilangin
# minjem : minjem
# bank : bank
# krg : krg
# nggak : nggak
# bkl : bkl
# hrga : hrga
# brg : brg
# kampanye : kampanye
# top : top
# debati : debat
# capres : capres
# jagoan : jago
# masing : masing
# telingga : telingga
# nutup : nutup
# bisanya : bisa
# ekonom : ekonom
# maknanya : makna
# konotatif : konotatif
# periode : periode
# berturut : turut
# turut : turut
# kegiatan : giat
# ekonominya : ekonomi
# besarnya : besar
# sebelumnya : belum
# mcb : mcb
# gaperlu : gaperlu
# nggu : nggu
# kmrn : kmrn
# twit : twit
# serentak : serentak
# anjerrr : anjerrr
# markas : markas
# londoninggris : londoninggris
# ormas : ormas
# haram : haram
# dinegeri : negeri
# kafir : kafir
# sampingan : samping
# ngadepin : ngadepin
# gajah : gajah
# duduk : duduk
# nga : nga
# terlibat : libat
# pinjol : pinjol
# ngausa : ngausa
# kalopun : kalo
# aja… : aja
# ngarep : ngarep
# instrumen : instrumen
# serok… : serok
# hahahahaha : hahahahaha
# produk : produk
# lokal : lokal
# muter : muter
# hha : hha
# kinerja : kerja
# dinilai : nilai
# doakan : doa
# terhindar : hindar
# ekonomiamin : ekonomiamin
# tuhanku : tuhan
# andai : andai
# pangkat : pangkat
# alesan : alesan
# ditanya : tanya
# kawin : kawin
# besoknya : besok
# resesilaganya : resesilaganya
# so : so
# persoalan : soal
# ko : ko
# jalan : jalan
# klean : klean
# kecewakan : kecewa
# paceklik : paceklik
# sulitmudahan : sulitmudahan
# baikbaik : baikbaik
# yakalopun : yakalopun
# lahamintetap : lahamintetap
# merchs : merchs
# wkakwkwkwk : wkakwkwkwk
# nanya : nanya
# jawabannya : jawab
# gangaruh : gangaruh
# gapunya : gapunya
# apaan : apa
# negaranegara : negaranegara
# diramalkan : ramal
# oleh : oleh
# desa : desa
# mengambil : ambil
# peran : peran
# sesuai : sesuai
# masingmasing : masingmasing
# kemendespdtt : kemendespdtt
# sdgsdesa : sdgsdesa
# percayadesa : percayadesa
# desabisa : desabisa
# mulaidaridesa : mulaidaridesa
# muterin : muterin
# ngajakin : ngajakin
# diundur : undur
# resignnya : resignnya
# jurus : jurus
# jitu : jitu
# mendang : dang
# wajib : wajib
# berasa : asa
# hasilnya : hasil
# tetangga : tetangga
# oke : oke
# duhh : duhh
# enak : enak
# kopi : kopi
# mulut : mulut
# pedes : pedes
# mumpung : mumpung
# promo : promo
# begitu : begitu
# siklus : siklus
# peringati : ingat
# sedunia : dunia
# bertani : tan
# solusi : solusi
# hahahahahahha : hahahahahahha
# defaultnye : defaultnye
# blangsak : blangsak
# gatakut : gatakut
# masjid : masjid
# sepi : sepi
# shadaqohku : shadaqohku
# berkurang : kurang
# resesipadahal : resesipadahal
# segini : gin
# surgatapi : surgatapi
# relate : relate
# dirimu : diri
# modelan : model
# abdurrahman : abdurrahman
# ibn : ibn
# auf : auf
# isded : isded
# kesel : kesel
# batunya : batu
# ngiritngirit : ngiritngirit
# ketarketir : ketarketir
# penghasilanku : hasil
# saling : saling
# istri : istri
# that : that
# kutahu : tahu
# hahay : hahay
# kerjaannya : kerja
# menanam : tanam
# padi : padi
# mayur : mayur
# ninjaku : ninjaku
# mudahnya : mudah
# pelosok : pelosok
# negri : negri
# betulll : betulll
# guna : guna
# puasa : puasa
# daud : daud
# ngebanting : ngebanting
# dibanting : banting
# yalah : yalah
# ngatur : ngatur
# debit : debit
# gaya : gaya
# gayaan : gaya
# ngudut : ngudut
# indomalay : indomalay
# pertanda : tanda
# pikiran : pikir
# segitu : segitu
# parnonya : parnonya
# hahahahahaha : hahahahahaha
# tolong : tolong
# ributin : ributin
# ngetweet : ngetweet
# nguli : nguli
# syulit : syulit
# melupakan : lupa
# reyhan : reyhan
# relatifitas : relatifitas
# berkembang : kembang
# revolusi : revolusi
# industri : industri
# missqueen : missqueen
# bangkrut : bangkrut
# ‍ :
# lusa : lusa
# sok : sok
# sokan : sok
# hope : hope
# bijak : bijak
# dipaksain : dipaksain
# memungkinkan : mungkin
# agak : agak
# komo : komo
# kebetulan : betul
# efek : efek
# commodity : commodity
# boom : boom
# meskipun : meski
# kemana : mana
# pandangan : pandang
# aktif : aktif
# koreksi : koreksi
# tambahin : tambahin
# cuih : cuih
# gelapnya : gelap
# at : at
# least : least
# beraktivitas : aktivitas
# campaign : campaign
# mark : mark
# words : words
# just : just
# fine : fine
# ksl : ksl
# dilebihin : dilebihin
# apalg : apalg
# yt : yt
# ujungnya : ujung
# kelas : kelas
# wkakak : wkakak
# iyo : iyo
# seh : seh
# kene : kene
# dikeki : keki
# duek : duek
# ewu : ewu
# mangan : mangan
# mslh : mslh
# opo : opo
# podo : podo
# ambek : ambek
# menghadapai : menghadapai
# fix : fix
# europe : europe
# untukku : untuk
# domino : domino
# cetak : cetak
# lari : lari
# crypto : crypto
# perusahaan : usaha
# teknologi : teknologi
# digital : digital
# beredar : edar
# naikin : naikin
# tiati : tiati
# sisanya : sisa
# bung : bung
# hebohnya : heboh
# fak : fak
# cmn : cmn
# njir : njir
# parno : parno
# nggilani : nggilani
# kesiapan : kesiap
# include : include
# didlmnya : didlmnya
# mamak : mamak
# bapakmu : bapak
# mikirke : mikirke
# ngunuuu : ngunuuu
# lhoo : lhoo
# wes : wes
# moco : moco
# hubungannya : hubung
# ato : ato
# angkat : angkat
# tangan : tangan
# jiakh : jiakh
# alamat : alamat
# restu : restu
# ibunda : ibunda
# pasangan : pasang
# akad : akad
# ambe : ambe
# sopo : sopo
# yayuk : yayuk
# pengusaha : usaha
# lh : lh
# giliran : gilir
# lulus : lulus
# tiba : tiba
# diomongkan : omong
# jauh : jauh
# patut : patut
# dicurigai : curiga
# startup : startup
# melakukan : laku
# carrier : carrier
# kesentuh : sentuh
# samsek : samsek
# bukalapak : bukalapak
# new : new
# gan : gan
# bnib : bnib
# muncak : muncak
# ‍️ :
# terkini : kini
# mie : mie
# sedaap : sedaap
# singapura : singapura
# sodara : sodara
# paijo : paijo
# ngoahahahahahaha : ngoahahahahahaha
# tempa : tempa
# keadaan : ada
# mundur : mundur
# mingguan : minggu
# financial : financial
# etc : etc
# insight : insight
# planning : planning
# amitamit : amitamit
# kejadianeh : kejadianeh
# dicancel : dicancel
# parahnya : parah
# disangkut : sangkut
# pautin : pautin
# ngeraguin : ngeraguin
# kuasa : kuasa
# aplikasi : aplikasi
# culasnya : culas
# gulung : gulung
# tikar : tikar
# dibodohi : bodoh
# nyinggung : nyinggung
# dapur : dapur
# hatihati : hatihati
# membaik : baik
# salintempel : salintempel
# komen : komen
# wangy : wangy
# pantes : pantes
# jepang : jepang
# berlomba : lomba
# pasarkan : pasar
# terbang : terbang
# aeee : aeee
# oeee : oeee
# lestikejora : lestikejora
# kehilangan : hilang
# income : income
# menghilangkan : hilang
# permanen : permanen
# semampu : mampu
# ditakutkan : takut
# dobosan : dobosan
# maniac : maniac
# galau : galau
# pergi : pergi
# nyata : nyata
# nasib : nasib
# overthinking : overthinking
# sinyal : sinyal
# moneter : moneter
# ketat : ketat
# sentral : sentral
# disebut : sebut
# relatif : relatif
# tahan : tahan
# analisis : analisis
# cnnindonesia : cnnindonesia
# ibuk : ibuk
# bodo : bodo
# panen : panen
# ngisi : ngisi
# stunting : stunting
# pkm : pkm
# wkwkww : wkwkww
# link : link
# takjub : takjub
# menjelaskan : jelas
# tidur : tidur
# kebawa : bawa
# mimpi : mimpi
# berlebih : lebih
# ngapangapain : ngapangapain
# lesunya : lesu
# benar : benar
# dirasain : dirasain
# lebaran : lebaran
# perlahan : perlahan
# penjualan : jual
# latah : latah
# drastis : drastis
# ginian : ginian
# darilama : darilama
# tweet : tweet
# dibawahnya : bawah
# rep : rep
# terpengaruh : pengaruh
# selebtwot : selebtwot
# kebayang : bayang
# tiwas : tiwas
# marai : mara
# ben : ben
# rodok : rodok
# termotivasi : motivasi
# harihari : harihari
# maleh : maleh
# gemerlap : gemerlap
# peler : peler
# yess : yess
# jujur : jujur
# capekk : capekk
# ngeliatnya : ngeliatnya
# berusaha : usaha
# ora : ora
# ambrol : ambrol
# pertahanan : tahan
# ditawarin : ditawarin
# sisir : sisir
# bergambar : gambar
# princess : princess
# tiana : tiana
# rb : rb
# siang : siang
# roi : roi
# meleset : meleset
# sekedar : dar
# laaah : laaah
# bear : bear
# market : market
# saatnya : saat
# develop : develop
# jaringan : jaring
# sosialisasi : sosialisasi
# gagasan : gagas
# ayo : ayo
# menabunggg : menabunggg
# taiii : taiii
# segabrek : segabrek
# zaman : zaman
# hotwil : hotwil
# ofc : ofc
# attracts : attracts
# clicks : clicks
# terlihat : lihat
# seram : seram
# accept : accept
# denial : denial
# mal : mal
# restoran : restoran
# dek : dek
# rasarasa : rasarasa
# honor : honor
# acc : acc
# bulanan : bulan
# dipotong : potong
# insyaaallah : insyaaallah
# sugar : sugar
# daddy : daddy
# pencerahan : cerah
# sekaligus : sekaligus
# pembahasan : bahas
# pakde : pakde
# bude : bude
# tante : tante
# omom : omom
# inflansi : inflansi
# duwit : duwit
# gx : gx
# anjay : anjay
# ckck : ckck
# esg : esg
# investment : investment
# fosil : fosil
# seret : seret
# tambang : tambang
# ditutup : tutup
# recovery : recovery
# supply : supply
# blokade : blokade
# sumber : sumber
# bidang : bidang
# agk : agk
# mahasiswa : mahasiswa
# lakuin : lakuin
# saking : saking
# cw : cw
# work : work
# nyusun : nyusun
# joblesss : joblesss
# sepertiku : seperti
# hati² : hati
# ...
# bertopeng : topeng
# bawabawa : bawabawa
# mengedukasi : edukasi
# abal : abal
# aoka : aoka
# ½ons : ons
# bks : bks
# sepak : sepak
# penanggulangan : tanggulang
# haven : haven
# nayk : nayk
# stocks : stocks
# rela : rela
# minumnya : minum
# gratisss : gratisss
# berkelas : kelas
# obralan : obral
# penempatan : tempat
# meetingnya : meetingnya
# arahbangsa : arahbangsa
# sllu : sllu
# mnabung : mnabung
# dita : dita
# airjordan : airjordan
# tsd : tsd
# kpsp : kpsp
# boys : boys
# reformasi : reformasi
# peraya : raya
# sekte : sekte
# mahalini : mahalini
# caca : caca
# bhaiq‍️ : bhaiq
# uaman : uaman
# nko : nko
# khan : khan
# lebib : lebib
# curang : curang
# segilintir : segilintir
# segelintir : gelintir
# kehabisan : habis
# takuttt : takuttt
# berlapis : lap
# keenam : enam
# roelz : roelz
# laki² : laki
# jambi : jambi
# seingatku : ingat
# patungan : patungan
# urg : urg
# kontras : kontras
# memproduksi : produksi
# cendera : cendera
# seenaknya : enak
# berjamaah : jamaah
# guisss : guisss
# mmikirkan : mmikirkan
# hedeh : hedeh
# kendurkan : kendur
# desas : desas
# desus : desus
# rejekinya : rejekinya
# simpatisan : simpatisan
# sebodoh : bodoh
# resist : resist
# pretty : pretty
# lippies : lippies
# gangguin : gangguin
# ckckc : ckckc
# bodohnyaa : bodohnyaa
# chrisyeeros : chrisyeeros
# sinting : sinting
# pernahnya : pernah
# ragukan : ragu
# drained : drained
# intvw : intvw
# rehat : rehat
# bntaran : bntaran
# heuuuuuuuuuuuu : heuuuuuuuuuuuu
# intervw : intervw
# krjaannya : krjaannya
# ekstrm : ekstrm
# adilan : adil
# lumrah : lumrah
# paketan : paket
# ramah : ramah
# ngopo : ngopo
# ngang : ngang
# ngeng : ngeng
# ngong : ngong
# mulutmu : mulut
# junjungan : junjung
# aktor : aktor
# mesum : mesum
# menguatnya : kuat
# melambatkan : lambat
# teriakin : teriakin
# ngetwit : ngetwit
# bangkeeeeee : bangkeeeeee
# dj : dj
# wrong : wrong
# ajakaga : ajakaga
# sektorindusti : sektorindusti
# brandnya : brandnya
# melirik : lirik
# tahuntahun : tahuntahun
# ndes : ndes
# tentangnya : tentang
# stussy : stussy
# livin : livin
# babak : babak
# belur : bur
# utkmu : utkmu
# globalnya : global
# bangkeeee : bangkeeee
# ketimpangan : timpang
# bagaikan : bagai
# thumbnail : thumbnail
# citra : citra
# tipuan : tipu
# shoope : shoope
# kerugian : rugi
# sampoerna : sampoerna
# sederetan : deret
# kitamesti : kitamesti
# curigaa : curigaa
# bersamasby : bersamasby
# demokratntb : demokratntb
# produkmu : produk
# mandang : mandang
# pertolongan : tolong
# serukan : seru
# grassroot : grassroot
# menghidupkan : hidup
# terwaras : waras
# nakutinnakutin : nakutinnakutin
# ngajarin : ngajarin
# nun : nun
# swalayan : swalayan
# megah : megah
# diantisipasi : antisipasi
# meluasnya : luas
# bedampak : bedampak
# meluas : luas
# jedamediaindonesia : jedamediaindonesia
# ttd : ttd
# mencampuradukan : mencampuradukan
# mengaitkan : kait
# wujud : wujud
# sedemikian : demikian
# luasnya : luas
# gelandangan : gelandang
# menimbun : timbun
# sembunyikan : sembunyi
# dipertontonkan : tonton
# probabilitasnya : probabilitas
# std : std
# ingetin : ingetin
# perdikit : dikit
# coklat : coklat
# melempem : melempem
# ngeprediksi : ngeprediksi
# bisabisanya : bisabisanya
# pemgaruh : pemgaruh
# iniitu : iniitu
# milik : milik
# medenni : medenni
# jebul : jebul
# ngekei : ngekei
# seingat : ingat
# keterkaitan : kait
# sulid : sulid
# them : them
# membeberkan : beber
# haramnya : haram
# diperingatkan : ingat
# wni : wni
# blabla : blabla
# stc : stc
# plesiden : plesiden
# biasakan : biasa
# ketak : ketak
# ketik : ketik
# dongo : dongo
# piara : piara
# bestprofit : bestprofit
# husnuzon : husnuzon
# suuzon : suuzon
# payahnya : payah
# disclaimer : disclaimer
# fact : fact
# untungnyaada : untungnyaada
# mematahkan : patah
# kerjaa : kerjaa
# trimakasih : trimakasih
# pemerhati : perhati
# cekrak : cekrak
# cekrek : cekrek
# selfie : selfie
# jiwamuda : jiwamuda
# berceritasampaitua : berceritasampaitua
# asn : asn
# adrenalin : adrenalin
# disamain : disamain
# obatnya : obat
# kuliahnya : kuliah
# yuklah : yuk
# matasby : matasby
# ajasih : ajasih
# tepatnya : tepat
# baiik : baiik
# xixixihihihuahahahahahahahahahahahahahahahaha : xixixihihihuahahahahahahahahahahahahahahahaha
# gonjang : gonjang
# ganjing : ganjing
# ohhhhh : ohhhhh
# progam : progam
# jkp : jkp
# industries : industries
# mnc : mnc
# basenya : basenya
# discuss : discuss
# pic : pic
# royal : royal
# canine : canine
# pasir : pasir
# eek : eek
# slav : slav
# perdamaian : damai
# rupiahkeokrp : rupiahkeokrp
# keok : keok
# bermalasmalasan : bermalasmalasan
# text : text
# ml : ml
# bcara : bcara
# perintilan : perintilan
# keluarkan : keluar
# kuhadapi : hadap
# kepikirannya : pikir
# interview : interview
# burst : burst
# saklek : saklek
# tencent : tencent
# bijaksana : bijaksana
# mensupport : mensupport
# isu² : isu
# kegaduhan : gaduh
# kader² : kader
# financialcorner : financialcorner
# brsm : brsm
# valencia : valencia
# fabianbacfp : fabianbacfp
# fp : fp
# sonora : sonora
# fm : fm
# konter : konter
# dhil : dhil
# mematuk : patuk
# ekornya : ekor
# konsepnyangirit : konsepnyangirit
# uanglu : uanglu
# tersimpan : simpan
# lm : lm
# spay : spay
# keinginannya : ingin
# ngelobi : ngelobi
# mesen : mesen
# menghukum : hukum
# pertandingan : tanding
# puseng : puseng
# anjer : anjer
# modalnya : modal
# wisatawan : wisatawan
# karenaaa : karenaaa
# ️uang️ : uang
# banyak²in : banyak in
# insa : insa
# jeneng : jeneng
# ical : ical
# celukan : celuk
# konsumsinya : konsumsi
# kayaq : kayaq
# beauty : beauty
# pancingan : pancing
# diperbanyak : banyak
# kitaaa : kitaaa
# adjem : adjem
# djp : djp
# sunset : sunset
# tercapai : capai
# ngebantuuu : ngebantuuu
# tulung : tulung
# itungke : itungke
# kiro : kiro
# nggowo : nggowo
# estimasi : estimasi
# daycare : daycare
# lc : lc
# atpm : atpm
# inden : inden
# palisade : palisade
# kejatuhan : jatuh
# diungkapkan : ungkap
# pikiranku : pikir
# planing : planing
# dls : dls
# wisan : wisan
# digembar : digembar
# gemborkan : gembor
# malangnya : malang
# negeriku : negeri
# atuhlah : atuhlah
# maenan : maenan
# memaklumi : maklum
# kpi : kpi
# dzolim : dzolim
# ewe : ewe
# pengusahamilenialmakinmaju : pengusahamilenialmakinmaju
# membantah : ban
# dunia… : dunia
# mengajakku : ajak
# baku : baku
# mnrut : mnrut
# maturnuwun : maturnuwun
# inpormasinya : inpormasinya
# saatx : saatx
# vga : vga
# pamer : pamer
# abc : abc
# ngurah : ngurah
# gg : gg
# usdc : usdc
# melambatbahkan : melambatbahkan
# resesikita : resesikita
# west : west
# java : java
# wjis : wjis
# trans : trans
# bandungrabu : bandungrabu
# ridwankamilpresiden : ridwankamilpresiden
# indonesiahijau : indonesiahijau
# indonesiajuara : indonesiajuara
# gojekin : gojekin
# kecilan : kecil
# rezesi : rezesi
# treafting : treafting
# rajia : rajia
# unfaedah : unfaedah
# introvert : introvert
# antisosial : antisosial
# broadcast : broadcast
# memuakkan : muak
# penggunaan : guna
# taqwa : taqwa
# kompetensi : kompetensi
# candaan : canda
# ketularan : tular
# lsg : lsg
# nymp : nymp
# mempersulit : sulit
# baiklah : baik
# tks : tks
# rupa : rupa
# menggambar : gambar
# speaking : speaking
# mitologi : mitologi
# yunani : yunani
# beradaban : adab
# terbentuk : bentuk
# searching : searching
# inginkan : ingin
# pembalap : balap
# valentino : valentino
# kompasbisnis : kompasbisnis
# saksikan : saksi
# chanel : chanel
# pimai : pimai
# mansion : mansion
# mledak : mledak
# bjuang : bjuang
# sebabakibat : sebabakibat
# ogah : ogah
# ngewujudin : ngewujudin
# jkowi : jkowi
# brtambah : brtambah
# pngngguran : pngngguran
# sran : sran
# trbiasa : trbiasa
# mngnggur : mngnggur
# sbaiknya : sbaiknya
# training : training
# plajari : plajari
# oprasional : oprasional
# kuyid : kuyid
# cluster : cluster
# pedihnya : pedih
# muternya : muternya
# oksigen : oksigen
# ngegembor : ngegembor
# ngedrive : ngedrive
# empower : empower
# setimen : setimen
# pancet : pancet
# duwek : duwek
# interpretasi : interpretasi
# western : western
# sentuh : sentuh
# sagafx : sagafx
# tradingbersamasagafx : tradingbersamasagafx
# beritakeuangandanbisnis : beritakeuangandanbisnis
# ngeluncurin : ngeluncurin
# missile : missile
# nasehatnya : nasehat
# kenanya : kena
# misleading : misleading
# yami : yami
# resesibukan : resesibukan
# leh : leh
# taboeng : taboeng
# bentak : bentak
# sistuy : sistuy
# duitna : duitna
# beak : beak
# sapopoe : sapopoe
# giru : giru
# devosito : devosito
# banding : banding
# sendal : sendal
# matj : matj
# praktikum : praktikum
# kepulauan : pulau
# portugal : portugal
# polygon : polygon
# meluncurkan : luncur
# testnet : testnet
# layer : layer
# hermez : hermez
# tonton🇲🇨 : tonton
# nyelesain : nyelesain
# perundingan : runding
# nyuntik : nyuntik
# ukr : ukr
# ru : ru
# suntik : suntik
# belon : belon
# perparah : parah
# copium : copium
# mengalahkan : kalah
# ketatnya : ketat
# yookk : yookk
# uangkuuu : uangkuuu
# naaahhh : naaahhh
# kangen : kangen
# ber : ber
# santy : santy
# disembunyikan : sembunyi
# diikuti : ikut
# policymakers : policymakers
# mengakuinya : aku
# catatan : catat
# labanya : laba
# konteks : konteks
# mislead : mislead
# serahin : serahin
# teamnya : teamnya
# perjuangannya : juang
# eling : eling
# liburannya : libur
# nyetel : nyetel
# berbunga : bunga
# scenario : scenario
# either : either
# ngobrils : ngobrils
# daftarkan : daftar
# persiapanresesi : persiapanresesi
# extraordinary : extraordinary
# claims : claims
# require : require
# evidence : evidence
# mainmain : mainmain
# satusatunya : satusatunya
# bussines : bussines
# invest️ : invest
# sutanto : sutanto
# tumpuk : tumpuk
# pundi : pundi
# alihkan : alih
# membuatku : buat
# bangetlah‍ : banget
# resesikudu : resesikudu
# ngedumelnya : ngedumel
# opsinya : opsi
# bendahara : bendahara
# chalmers : chalmers
# economicindicator : economicindicator
# audusd : audusd
# semua²nya : semua nya
# resesi² : resesi
# cerai : cerai
# tasya : tasya
# farasya : farasya
# talks : talks
# nice : nice
# answer : answer
# dihadapin : dihadapin
# sebisanya : bisa
# coomingsoon : coomingsoon
# bedaknya : bedak
# ketebalan : tebal
# penawaran : tawar
# melalulalang : melalulalang
# peredanya : reda
# berawal : awal
# ngaji : ngaji
# bergantinya : ganti
# akdjsjkdksk : akdjsjkdksk
# blas : blas
# setronk : setronk
# ornag : ornag
# nyungsep : nyungsep
# siapp : siapp
# jopersiapan : jopersiapan
# dinding : dinding
# hiasan : hias
# sangatsangat : sangatsangat
# dukun : dukun
# anchoring : anchoring
# channelnya : channelnya
# antimainstream : antimainstream
# mempromosikan : promosi
# telekomunikasi : telekomunikasi
# kaburu : kaburu
# mulu… : mulu
# travelling : travelling
# nbung : nbung
# ♡ :
# pagi² : pagi
# yall : yall
# biasa² : biasa
# hura² : hura
# including : including
# britane : britane
# palhan : palhan
# maksudku : maksud
# duite : duite
# hmmmmm : hmmmmm
# lahliat : lahliat
# petunjuk : tunjuk
# × :
# nyut : nyut
# nyutan : nyut
# konserrrr : konserrrr
# selebriti : selebriti
# twitt : twitt
# pickaw : pickaw
# dicariin : dicariin
# collector : collector
# ygkaya : ygkaya
# baratamerika : baratamerika
# kuaminkan : amin
# masker : masker
# duniaimf : duniaimf
# digitalisasi : digitalisasi
# chindo : chindo
# akrindo : akrindo
# cukai : cukai
# dirundung : rundung
# arrahmahcom : arrahmahcom
# pastiiii : pastiiii
# hm : hm
# merangkak : rangkak
# mengikis : kikis
# nggaknya : nggaknya
# retinolnya : retinolnya
# avoskin : avoskin
# vit : vit
# cnya : cnya
# laneige : laneige
# niacinamide : niacinamide
# centellanya : centellanya
# aubree : aubree
# ingredientsnya : ingredientsnya
# ⚘⚘ :
# mutar : mutar
# products : products
# convesional : convesional
# mempergunakan : guna
# unfollow : unfollow
# terkotakkotakan : terkotakkotakan
# kesaktian : sakti
# meremehkan : remeh
# ajh : ajh
# eropaus : eropaus
# pore : pore
# ditmpt : ditmpt
# otoriter : otoriter
# ditipu : tipu
# tanduk : tanduk
# sepeda : sepeda
# bacalah : baca
# ketambahan : tambah
# jobdesk : jobdesk
# ditangan : tang
# moratmarit : moratmarit
# recovering : recovering
# historically : historically
# bipeng : bipeng
# pemghasil : pemghasil
# diresesikan : resesi
# pppk : pppk
# smartbusinesstalk : smartbusinesstalk
# kemaren² : kemaren
# daerahku : daerah
# own : own
# kic : kic
# satttt : satttt
# lebihi : lebih
# airing : airing
# tuned : tuned
# {'seiring': 'iring', 'dg': 'dg', 'resesi': 'resesi', 'proyeksi': 'proyeksi', 'gelap': 'gelap', 'ekonomi': 'ekonomi', 'global': 'global', 'adlg': 'adlg', 'kunci': 'kunci', 'logis': 'logis', 'dri': 'dri', 'penerapan': 'terap', 'sistem': 'sistem', 'kapitalisme': 'kapitalisme', 'mulai': 'mulai', 'menguasai': 'kuasa', 'dunia': 'dunia', 'abad': 'abad', 'apalagi': 'apalagi', 'amerika': 'amerika', 'menaklukkan': 'takluk', 'rival': 'rival', 'ideologix': 'ideologix', 'monarkiselengkapnya': 'monarkiselengkapnya', 'serbaserbi': 'serbaserbi', 'islamkaffah': 'islamkaffah', 'imf': 'imf', 'memproyeksi': 'proyeksi', 'tahun': 'tahun', 'ini': 'ini', 'diakibatkan': 'akibat', 'banyak': 'banyak', 'covid': 'covid', 'imbas': 'imbas', 'invsi': 'invsi', 'rusi': 'rusi', 'ukrina': 'ukrina', 'mampukah': 'mampu', 'mengatasinya': 'atas', 'simak': 'simak', 'videonya': 'video', 'mmc': 'mmc', 'krn': 'krn', 'merugi': 'rugi', 't': 't', 'ud': 'ud', 'akibat': 'akibat', 'penyebabx': 'penyebabx', 'amp': 'amp', 'dihadapkan': 'hadap', 'ancaman': 'ancam', 'krisis': 'krisis', 'invasi': 'invasi', 'rusia': 'rusia', 'ukraina': 'ukraina', 'perubahan': 'ubah', 'ikliminilh': 'ikliminilh', 'akibt': 'akibt', 'presiden': 'presiden', 'ri': 'ri', 'susilo': 'susilo', 'bambang': 'bambang', 'yudhoyono': 'yudhoyono', 'merasa': 'rasa', 'resah': 'resah', 'hambat': 'hambat', 'upaya': 'upaya', 'atasi': 'atas', 'warming': 'warming', 'dan': 'dan', 'justru': 'justru', 'sibuk': 'sibuk', 'masalah': 'masalah', 'geopolitik': 'geopolitik', 'kian': 'kian', 'runcing': 'runcing', 'lantas': 'lantas', 'seberapa': 'berapa', 'besar': 'besar', 'perhatian': 'perhati', 'pemimpin': 'pimpin', 'utk': 'utk', 'selamatkan': 'selamat', 'bumi': 'bumi', 'udha': 'udha', 'ngerasain': 'ngerasain', 'wkwkwk': 'wkwkwk', 'bismillah': 'bismillah', 'siap': 'siap', 'menjalani': 'jalan', 'menghadapinya': 'hadap', 'yang': 'yang', 'lahir': 'lahir', 'aja': 'aja', 'biasa': 'biasa', 'she': 'she', 'said': 'said', 'depan': 'depan', 'mau': 'mau', 'loh': 'loh', 'yakin': 'yakin', 'resign': 'resign', 'arghhhh': 'arghhhh', 'diprediksi': 'prediksi', 'mengatasi': 'atas', 'kapitalis': 'kapitalis', 'akan': 'akan', 'thn': 'thn', 'selengkaonya': 'selengkaonya', 'sedang': 'sedang', 'mengalami': 'alami', 'berikut': 'ikut', 'si': 'si', 'anjing': 'anjing', 'mending': 'mending', 'suruh': 'suruh', 'kerja': 'kerja', 'nabung': 'nabung', 'soalnya': 'soal', 'war': 'war', 'sama': 'sama', 'netijen': 'netijen', 'gak': 'gak', 'bakal': 'bakal', 'bikin': 'bikin', 'tabungan': 'tabung', 'gendut': 'gendut', 'thx': 'thx', 'gue': 'gue', 'jadi': 'jadi', 'paham': 'paham', 'dikit': 'dikit', 'sm': 'sm', 'semoga': 'moga', 'aku': 'aku', 'kita': 'kita', 'semua': 'semua', 'aman': 'aman', 'bintang': 'bintang', 'mares': 'mares', 'balikan': 'balik', 'islam': 'islam', 'kaffah': 'kaffah', 'buat': 'buat', 'klen': 'klen', 'ajakajak': 'ajakajak', 'hangout': 'hangout', 'sorry': 'sorry', 'tolak': 'tolak', 'persiapan': 'siap', 'menghadapi': 'hadap', 'bayangin': 'bayangin', 'kalo': 'kalo', 'orang': 'orang', 'sampai': 'sampai', 'indonesia': 'indonesia', 'keluar': 'keluar', 'statement': 'statement', 'bersyukur': 'syukur', 'kena': 'kena', 'di': 'di', 'negara': 'negara', 'pedalaman': 'dalam', 'afrika': 'afrika', 'makan': 'makan', 'lho': 'lho', 'bener': 'bener', 'sih': 'sih', 'tinggal': 'tinggal', 'lainnya': 'lain', 'kiat': 'kiat', 'umkm': 'umkm', 'hadapi': 'hadap', 'pakar': 'pakar', 'sebut': 'sebut', 'tak': 'tak', 'berdampak': 'dampak', 'langsung': 'langsung', 'alasannya': 'alas', 'tempobisnis': 'tempobisnis', 'ngapain': 'ngapain', 'mesti': 'mesti', 'takut': 'takut', 'prediksi': 'prediksi', 'emang': 'emang', 'selama': 'lama', 'hidupmu': 'hidup', 'sulit': 'sulit', 'sekarang': 'sekarang', 'penghasilanmu': 'hasil', 'dulu': 'dulu', 'antum': 'antum', 'udah': 'udah', 'duluan': 'duluan', 'ye': 'ye', 'harga': 'harga', 'minyak': 'minyak', 'mentah': 'mentah', 'anjlok': 'anjlok', 'pekan': 'pekan', 'kekhawatiran': 'khawatir', 'merebak': 'rebak', 'hargaminyakbumi': 'hargaminyakbumi', 'minus': 'minus' ...
# ------------------------
# Pandas Apply:   0%|          | 0/7617 [00:00<?, ?it/s]
# 0       [iring, dg, resesi, proyeksi, gelap, ekonomi, ...
# 1       [imf, proyeksi, ekonomi, global, gelap, tahun,...
# 2       [ekonomi, global, gelap, krn, rugi, t, ud, aki...
# 3       [presiden, ri, susilo, bambang, yudhoyono, ras...
# 4       [udha, ngerasain, resesi, wkwkwk, bismillah, s...
#                               ...
# 7612    [bank, dunia, imf, ulang, ingat, soal, resesi,...
# 7613    [now, airing, smartbusinesstalk, sama, yang, b...
# 7614    [kalo, amit, jadi, resesi, mo, nikah, tahun, d...
# 7615    [harga, minyak, merosot, hampir, persen, akhir...
# 7616    [zodiak, mungkin, besar, tahan, resesi, virgo,...
# Name: stemmed_tweet, Length: 7617, dtype: object

# %% [markdown]
# 2.5 Melihat Kata Terbanyak

# %%
FreqWord = pd.DataFrame(all_freq_words.items(), columns=['word', 'frequency']).sort_values(by='frequency', ascending=False)
# for ind in FreqWord.index:
#     print(FreqWord['word'][ind], FreqWord['frequency'][ind])

# %%
FreqWord#sebelum di drop
# Out:
#             word  frequency
# 2         resesi       8338
# 5        ekonomi       1313
# 28         tahun       1197
# 97         depan       1075
# 6         global        842
# ...          ...        ...
# 3908       nuker          1
# 3909   posisinya          1
# 9010         dor          1
# 9009     tunggal          1
# 14760      tuned          1
#
# [14761 rows x 2 columns]

# %%
df_final = dfc.copy()

# %%
dfc.shape
# Out:
# (7617, 9)

# %%
dfc.isnull().sum()
# Out:
# Date               0
# User               0
# Number of likes    0
# Tweeted from       0
# Tweets             0
# clear              0
# token_tweets       0
# freq_words         0
# stemmed_tweet      0
# dtype: int64

# %%
dfc['clear'].isnull().sum()
# Out:
# 0

# %%
df_final = dfc.drop(dfc[dfc.clear == ''].index)

# %%
dfc["clear"].duplicated().sum()
# Out:
# 332

# %%
df_final.drop_duplicates(subset='clear',inplace=True)

# %%
df_final.shape
# Out:
# (7285, 9)

# %% [markdown]
# 2.6 Labeling sentimen menggunakan lexicon based

# %%
# Determine sentiment polarity of tweets using indonesia sentiment lexicon (source : https://github.com/fajri91/InSet)
# Loads lexicon positive and negative data
lexicon_positive = dict()
import csv
with open('lexicon_dictionary/positive.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_positive[row[0]] = int(row[1])

lexicon_negative = dict()
import csv
with open('lexicon_dictionary/negative.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_negative[row[0]] = int(row[1])
        
# Function to determine sentiment polarity of tweets        
def sentiment_analysis_lexicon_indonesia(text):
    #for word in text:
    score = 0
    for word in text:
        if (word in lexicon_positive):
            score = score + lexicon_positive[word]
    for word in text:
        if (word in lexicon_negative):
            score = score + lexicon_negative[word]
    polarity=''
    s=0
    if (score > 0):
        polarity = 'positive'
        s=1
    elif (score < 0):
        polarity = 'negative'
        s=-1
    else:
        polarity = 'neutral'
        s=0
    return score, polarity, s

# %%
results = df_final['token_tweets'].apply(sentiment_analysis_lexicon_indonesia)
results = list(zip(*results))
df_final['polarity_score'] = results[0]
df_final['polarity'] = results[1]
df_final['score'] = results[2]
print(df_final['polarity'].value_counts())

df_final
# Out:
# negative    6587
# positive     519
# neutral      179
# Name: polarity, dtype: int64
#                            Date             User  Number of likes  \
# 0     2022-10-15 23:57:38+00:00  SurfaniSurfani3                0
# 1     2022-10-15 23:55:55+00:00      UmiHafizha1                1
# 2     2022-10-15 23:55:14+00:00    latifajulia77                1
# 3     2022-10-15 23:55:08+00:00        PDemokrat              142
# 4     2022-10-15 23:53:49+00:00      BELIEVEIN93                0
# ...                         ...              ...              ...
# 7609  2022-10-11 00:09:01+00:00      b1ngchillin                0
# 7611  2022-10-11 00:06:08+00:00       ghaits_ali                0
# 7613  2022-10-11 00:05:24+00:00     RadioSmartFM                0
# 7614  2022-10-11 00:04:48+00:00      sugarhnybee                0
# 7615  2022-10-11 00:01:07+00:00        tvOneNews                2
#
#              Tweeted from                                             Tweets  \
# 0     Twitter for Android  seiring dg Resesi proyeksi gelap ekonomi globa...
# 1     Twitter for Android  IMF memproyeksi ekonomi global akan gelap pd t...
# 2     Twitter for Android  ekonomi global Akan Gelap pd 2023 krn merugi 4...
# 3     Twitter for Android  Presiden ke-6 RI, Susilo Bambang Yudhoyono mer...
# 4     Twitter for Android  @jek___ Sebelum 2015 udha ngerasain resesi wkw...
# ...                   ...                                                ...
# 7609   Twitter for iPhone  persiapan resesi kontol how can i persiapin du...
# 7611              dlvr.it  Harga Minyak Jatuh Karena Kekhawatiran Resesi ...
# 7613            TweetDeck  NOW AIRING\n\n#SmartBusinessTalk bersama @Tung...
# 7614  Twitter for Android  Kalo amit2 jadi resesi yg mo nikah tahun depan...
# 7615              dlvr.it  Harga Minyak Merosot Hampir Dua Persen Pada Ak...
#
#                                                   clear  \
# 0     seiring dg resesi proyeksi gelap ekonomi globa...
# 1     imf memproyeksi ekonomi global gelap tahun ini...
# 2     ekonomi global gelap krn merugi t ud akibat re...
# 3     presiden ri susilo bambang yudhoyono merasa re...
# 4     udha ngerasain resesi wkwkwk bismillah siap me...
# ...                                                 ...
# 7609  persiapan resesi kontol how can i persiapin du...
# 7611  harga minyak jatuh kekhawatiran resesi lebihi ...
# 7613  now airing smartbusinesstalk bersama yang memb...
# 7614  kalo amit jadi resesi mo nikah tahun depan gmn...
# 7615  harga minyak merosot hampir persen akhir perda...
#
#                                            token_tweets  \
# 0     [seiring, dg, resesi, proyeksi, gelap, ekonomi...
# 1     [imf, memproyeksi, ekonomi, global, gelap, tah...
# 2     [ekonomi, global, gelap, krn, merugi, t, ud, a...
# 3     [presiden, ri, susilo, bambang, yudhoyono, mer...
# 4     [udha, ngerasain, resesi, wkwkwk, bismillah, s...
# ...                                                 ...
# 7609  [persiapan, resesi, kontol, how, can, i, persi...
# 7611  [harga, minyak, jatuh, kekhawatiran, resesi, l...
# 7613  [now, airing, smartbusinesstalk, bersama, yang...
# 7614  [kalo, amit, jadi, resesi, mo, nikah, tahun, d...
# 7615  [harga, minyak, merosot, hampir, persen, akhir...
#
#                                              freq_words  \
# 0     {'seiring': 1, 'dg': 1, 'resesi': 1, 'proyeksi...
# 1     {'imf': 1, 'memproyeksi': 1, 'ekonomi': 2, 'gl...
# 2     {'ekonomi': 2, 'global': 1, 'gelap': 1, 'krn':...
# 3     {'presiden': 1, 'ri': 1, 'susilo': 1, 'bambang...
# 4     {'udha': 1, 'ngerasain': 1, 'resesi': 1, 'wkwk...
# ...                                                 ...
# 7609  {'persiapan': 1, 'resesi': 1, 'kontol': 1, 'ho...
# 7611  {'harga': 1, 'minyak': 1, 'jatuh': 1, 'kekhawa...
# 7613  {'now': 1, 'airing': 1, 'smartbusinesstalk': 1...
# 7614  {'kalo': 1, 'amit': 1, 'jadi': 1, 'resesi': 1,...
# 7615  {'harga': 1, 'minyak': 1, 'merosot': 1, 'hampi...
#
#                                           stemmed_tweet  polarity_score  \
# 0     [iring, dg, resesi, proyeksi, gelap, ekonomi, ...              -8
# 1     [imf, proyeksi, ekonomi, global, gelap, tahun,...             -15
# 2     [ekonomi, global, gelap, krn, rugi, t, ud, aki...             -25
# 3     [presiden, ri, susilo, bambang, yudhoyono, ras...             -29
# 4     [udha, ngerasain, resesi, wkwkwk, bismillah, s...               5
# ...                                                 ...             ...
# 7609  [siap, resesi, kontol, how, can, i, persiapin,...             -12
# 7611  [harga, minyak, jatuh, khawatir, resesi, lebih...             -11
# 7613  [now, airing, smartbusinesstalk, sama, yang, b...              -9
# 7614  [kalo, amit, jadi, resesi, mo, nikah, tahun, d...             -16
# 7615  [harga, minyak, merosot, hampir, persen, akhir...             -12
#
#       polarity  score
# 0     negative     -1
# 1     negative     -1
# 2     negative     -1
# 3     negative     -1
# 4     positive      1
# ...        ...    ...
# 7609  negative     -1
# 7611  negative     -1
# 7613  negative     -1
# 7614  negative     -1
# 7615  negative     -1
#
# [7285 rows x 12 columns]

# %%
df_final
# Out:
#                            Date             User  Number of likes  \
# 0     2022-10-15 23:57:38+00:00  SurfaniSurfani3                0
# 1     2022-10-15 23:55:55+00:00      UmiHafizha1                1
# 2     2022-10-15 23:55:14+00:00    latifajulia77                1
# 3     2022-10-15 23:55:08+00:00        PDemokrat              142
# 4     2022-10-15 23:53:49+00:00      BELIEVEIN93                0
# ...                         ...              ...              ...
# 7609  2022-10-11 00:09:01+00:00      b1ngchillin                0
# 7611  2022-10-11 00:06:08+00:00       ghaits_ali                0
# 7613  2022-10-11 00:05:24+00:00     RadioSmartFM                0
# 7614  2022-10-11 00:04:48+00:00      sugarhnybee                0
# 7615  2022-10-11 00:01:07+00:00        tvOneNews                2
#
#              Tweeted from                                             Tweets  \
# 0     Twitter for Android  seiring dg Resesi proyeksi gelap ekonomi globa...
# 1     Twitter for Android  IMF memproyeksi ekonomi global akan gelap pd t...
# 2     Twitter for Android  ekonomi global Akan Gelap pd 2023 krn merugi 4...
# 3     Twitter for Android  Presiden ke-6 RI, Susilo Bambang Yudhoyono mer...
# 4     Twitter for Android  @jek___ Sebelum 2015 udha ngerasain resesi wkw...
# ...                   ...                                                ...
# 7609   Twitter for iPhone  persiapan resesi kontol how can i persiapin du...
# 7611              dlvr.it  Harga Minyak Jatuh Karena Kekhawatiran Resesi ...
# 7613            TweetDeck  NOW AIRING\n\n#SmartBusinessTalk bersama @Tung...
# 7614  Twitter for Android  Kalo amit2 jadi resesi yg mo nikah tahun depan...
# 7615              dlvr.it  Harga Minyak Merosot Hampir Dua Persen Pada Ak...
#
#                                                   clear  \
# 0     seiring dg resesi proyeksi gelap ekonomi globa...
# 1     imf memproyeksi ekonomi global gelap tahun ini...
# 2     ekonomi global gelap krn merugi t ud akibat re...
# 3     presiden ri susilo bambang yudhoyono merasa re...
# 4     udha ngerasain resesi wkwkwk bismillah siap me...
# ...                                                 ...
# 7609  persiapan resesi kontol how can i persiapin du...
# 7611  harga minyak jatuh kekhawatiran resesi lebihi ...
# 7613  now airing smartbusinesstalk bersama yang memb...
# 7614  kalo amit jadi resesi mo nikah tahun depan gmn...
# 7615  harga minyak merosot hampir persen akhir perda...
#
#                                            token_tweets  \
# 0     [seiring, dg, resesi, proyeksi, gelap, ekonomi...
# 1     [imf, memproyeksi, ekonomi, global, gelap, tah...
# 2     [ekonomi, global, gelap, krn, merugi, t, ud, a...
# 3     [presiden, ri, susilo, bambang, yudhoyono, mer...
# 4     [udha, ngerasain, resesi, wkwkwk, bismillah, s...
# ...                                                 ...
# 7609  [persiapan, resesi, kontol, how, can, i, persi...
# 7611  [harga, minyak, jatuh, kekhawatiran, resesi, l...
# 7613  [now, airing, smartbusinesstalk, bersama, yang...
# 7614  [kalo, amit, jadi, resesi, mo, nikah, tahun, d...
# 7615  [harga, minyak, merosot, hampir, persen, akhir...
#
#                                              freq_words  \
# 0     {'seiring': 1, 'dg': 1, 'resesi': 1, 'proyeksi...
# 1     {'imf': 1, 'memproyeksi': 1, 'ekonomi': 2, 'gl...
# 2     {'ekonomi': 2, 'global': 1, 'gelap': 1, 'krn':...
# 3     {'presiden': 1, 'ri': 1, 'susilo': 1, 'bambang...
# 4     {'udha': 1, 'ngerasain': 1, 'resesi': 1, 'wkwk...
# ...                                                 ...
# 7609  {'persiapan': 1, 'resesi': 1, 'kontol': 1, 'ho...
# 7611  {'harga': 1, 'minyak': 1, 'jatuh': 1, 'kekhawa...
# 7613  {'now': 1, 'airing': 1, 'smartbusinesstalk': 1...
# 7614  {'kalo': 1, 'amit': 1, 'jadi': 1, 'resesi': 1,...
# 7615  {'harga': 1, 'minyak': 1, 'merosot': 1, 'hampi...
#
#                                           stemmed_tweet  polarity_score  \
# 0     [iring, dg, resesi, proyeksi, gelap, ekonomi, ...              -8
# 1     [imf, proyeksi, ekonomi, global, gelap, tahun,...             -15
# 2     [ekonomi, global, gelap, krn, rugi, t, ud, aki...             -25
# 3     [presiden, ri, susilo, bambang, yudhoyono, ras...             -29
# 4     [udha, ngerasain, resesi, wkwkwk, bismillah, s...               5
# ...                                                 ...             ...
# 7609  [siap, resesi, kontol, how, can, i, persiapin,...             -12
# 7611  [harga, minyak, jatuh, khawatir, resesi, lebih...             -11
# 7613  [now, airing, smartbusinesstalk, sama, yang, b...              -9
# 7614  [kalo, amit, jadi, resesi, mo, nikah, tahun, d...             -16
# 7615  [harga, minyak, merosot, hampir, persen, akhir...             -12
#
#       polarity  score
# 0     negative     -1
# 1     negative     -1
# 2     negative     -1
# 3     negative     -1
# 4     positive      1
# ...        ...    ...
# 7609  negative     -1
# 7611  negative     -1
# 7613  negative     -1
# 7614  negative     -1
# 7615  negative     -1
#
# [7285 rows x 12 columns]

# %% [markdown]
# Visualisasi

# %%
fig, ax = plt.subplots(figsize = (6, 6))
sizes = [count for count in df_final['polarity'].value_counts()]
labels = list(df_final['polarity'].value_counts().index)
explode = (0.1, 0, 0)
ax.pie(x = sizes, labels = labels, autopct = '%1.1f%%', explode = explode, textprops={'fontsize': 14})
ax.set_title('Sentiment Polarity on Tweets Data', fontsize = 16, pad = 20)
plt.show()

# %%
pd.set_option('display.max_colwidth', 3000)
positive_tweets = df_final[df_final['polarity'] == 'positive']
positive_tweets = positive_tweets[['clear', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=False).reset_index(drop = True)
positive_tweets.index += 1
positive_tweets[0:10]
# Out:
#                                                                                                                                                                                                                                                     clear  \
# 1                     chief henry salah satu yg disadari resesi menambah jumlah dana tunai cash nah dana tunai semakin banyak tinggal diversifikasi kemanfaatannya minimal manfaat manfaat dana darurat manfaat dana likuid manfaat perlundungan asuransi
# 2       baru skripsian aja udh stress gini gimana ntar nyari kerja dapet kerja planning mau nikah pas nikah pas mau keluarga mikirin biaya anak biaya istri rumah keluarga mana resesi pas gua lulus cari kerja eh tp gua lulus semoga aja lulus ya allah
# 3                                                                                                         resesi global ini merupakan momentum pekerja membangun komunikasi baik manajemen perusahaan produksi tetap lancar lapangan kerja tetap tersedia
# 4                                                                    taunya waktu studi pengaruh resesi nilai tukar petani marginal ditinjau aspek ketahanan pangan studi kasus jateng menemukan kajian mendalam soal struktur sosial peran gender wkwkwk
# 5                                                                 bismillah semoga tahun depan meskipun resesi rejeki makin lancar melimpah aamiin rejeki melulu uang kan dikasih sehat dikelilingi orang baik masuk rejeki kan hehe goodluck buat smuwaa
# 6          arif gitu semua bilang prestasi² kalau bukan pakbu kita sdh resesibangkrut sejak dulu yang harusnya bersyukur pemerintahnya bersyukur sdh rakyat kaya indonesia nrimo ing pandum pasrah sama gusti allah coba punya rakyat manja kayak amerika
# 7                                                                                                                                     cm guyss semengerikan resesi kira kira biaya kuliah naek ya allah semoga diberikan rezeki kebaikan selalu ya aamiin
# 8                                                                                                         mau resesi kek mau ngga kek selama jiwa masih berada dalam genggaman allah rejeki masing org udah diatur selama ikhtiar dont scare just prepare
# 9                                                                                                     jadi asik kok gamenya kalau mau enjoy enjoy rilek santai yg punya kerjaan clientnya kaya bangke disinilah anda menenangkan diri resesi enjooy maaan
# 10  aduh galau banget deh covid kelar udah ngeringeri sedap dibikin galau ama resesi bawaannya jadi pengen belajar terus biar security depannya kalo aku sih cocoknya belajar rakamin academy sih kelasnya gratis tutornya top company keren bat dah asli
#
#     polarity_score  polarity
# 1               34  positive
# 2               27  positive
# 3               21  positive
# 4               19  positive
# 5               17  positive
# 6               17  positive
# 7               16  positive
# 8               16  positive
# 9               15  positive
# 10              15  positive

# %%
pd.set_option('display.max_colwidth', 3000)
negative_tweets = df_final[df_final['polarity'] == 'negative']
negative_tweets = negative_tweets[['clear', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=True)[0:10].reset_index(drop = True)
negative_tweets.index += 1
negative_tweets[0:10]
# Out:
#                                                                                                                                                                                                                                           clear  \
# 1                                          a thread keyword krisis amp resesi sedang hits dimanamana khususnya ranah online yang pro yang kontra yang percaya yang percaya ada yang apatis kedua istilah tersebut krisis amp resesi keniscayaan
# 2                                                                                     paham perbedaan resesi akibat penurunan ekonomi biasa sama resesi akibat perang jadi fokusnya bukan resesi penyebabnya lagian lebih ngeri depresi ekonomi
# 3    harapan captain indonesia agus harimurti siapa calon pemimpin muda disaat dunia politik mengarah perang dunia resesi intimidasi ekonomi memiliki mental baja tahan intimidasi paham peta konspirasi dia bukan seorang prajurit kelas dunia
# 4   yang kurang waras bicara atau kalian semua tanya yang paling tahu betul sri mulyani yang berkelit selalu masalah iklim perang dunia maka dunia resesi tanya dia ada gaji pegawai indonesia tahun kalian adu seperti ayam yg mematuk ekornya
# 5                    isunya gencar resesi tahun depan perkirannya bakal naik suku bunga karena neken inflasi akibat pandemi butuh spend duit sebanyak mungkin nggak collaps yang pelajari kamu besok mikir makangak gausah terlalu mikir resesi
# 6                            penentuan resesi ibarat ahli forensik otopsi ambil bukti sampai sini harap mengerti kalau resesi bukan barometer penting konsumen pada umumnya dan adanya resesi bukan tahun bukan patokan bisa ongkang kaki tidak
# 7                             lebih baik lunasi hutang resesi gini jangan terlalu berspekulasi sisa uang bikin usaha perputaran cepat pensiun harusnya hidup tenang beban mikirin hutang kalau paham soal riba usahakan dunia aman akhirat aman
# 8                                                dunia sedang menuju resesi ancaman perang dunia lebih mudah jatuh rasa marah benci lebih sulit menghindar narasi buzzerp kita ngga kalah kita harus terbitkan optimisme indonesia meniti badai
# 9                                                                                                                                                                           resesi resesi resesi resesi resesi resesi resesi apaan sih saaatttt
# 10                     khawatir resesi jangan berlebihan perlu dikhawatirkan inti masalahnya perang russiaukraina yanh berkelanjutan akan membawa dampak lebih buruk resesi sendiri gak melarang khawatir kok meluruskan istilah krisis ekonomi
#
#     polarity_score  polarity
# 1              -42  negative
# 2              -42  negative
# 3              -42  negative
# 4              -41  negative
# 5              -41  negative
# 6              -41  negative
# 7              -40  negative
# 8              -40  negative
# 9              -39  negative
# 10             -39  negative

# %%
# Visualize word cloud

list_words=''
for tweet in df_final['token_tweets']:
    for word in tweet:
        list_words += ' '+(word)

wordcloud = WordCloud(width = 600, height = 400, background_color = 'black', min_font_size = 10).generate(list_words)
fig, ax = plt.subplots(figsize = (8, 6))
ax.set_title('Word Cloud of Tweets Data', fontsize = 18)
ax.grid(False)
ax.imshow((wordcloud))
fig.tight_layout(pad=0)
ax.axis('off')
plt.show()

# %%
# nltk.FreqDist(sum(df_final['clear'].map(word_tokenize), []))
# list_words
tokens = nltk.tokenize.word_tokenize(list_words)
fdist=nltk.FreqDist(tokens)
fdist
# Out:
# FreqDist({'resesi': 7990, 'ekonomi': 1245, 'tahun': 1175, 'depan': 1057, 'aja': 813, 'mau': 785, 'global': 767, 'indonesia': 657, 'apa': 569, 'dunia': 565, ...})

# %%
def words_with_sentiment(text):
    positive_words=[]
    negative_words=[]
    for word in text:
        score_pos = 0
        score_neg = 0
        if (word in lexicon_positive):
            score_pos = lexicon_positive[word]
        if (word in lexicon_negative):
            score_neg = lexicon_negative[word]
        
        if (score_pos + score_neg > 0):
            positive_words.append(word)
        elif (score_pos + score_neg < 0):
            negative_words.append(word)
            
    return positive_words, negative_words

# %%
sentiment_words = df_final['token_tweets'].apply(words_with_sentiment)
sentiment_words = list(zip(*sentiment_words))
positive_words = sentiment_words[0]
negative_words = sentiment_words[1]

fig, ax = plt.subplots(1, 2,figsize = (12, 10))
list_words_postive=''
for row_word in positive_words:
    for word in row_word:
        list_words_postive += ' '+(word)
wordcloud_positive = WordCloud(width = 800, height = 600, background_color = 'black', colormap = 'Greens'
                               , min_font_size = 10).generate(list_words_postive)
ax[0].set_title('Word Cloud of Positive Words on Tweets Data \n (based on Indonesia Sentiment Lexicon)', fontsize = 14)
ax[0].grid(False)
ax[0].imshow((wordcloud_positive))
fig.tight_layout(pad=0)
ax[0].axis('off')

list_words_negative=''
for row_word in negative_words:
    for word in row_word:
        list_words_negative += ' '+(word)
wordcloud_negative = WordCloud(width = 800, height = 600, background_color = 'black', colormap = 'Reds'
                               , min_font_size = 10).generate(list_words_negative)
ax[1].set_title('Word Cloud of Negative Words on Tweets Data \n (based on Indonesia Sentiment Lexicon)', fontsize = 14)
ax[1].grid(False)
ax[1].imshow((wordcloud_negative))
fig.tight_layout(pad=0)
ax[1].axis('off')

plt.show()

# %%
df_final['Date'] = pd.to_datetime(df_final['Date']).dt.date

# %%
df_final.head(20)
# Out:
#           Date             User  Number of likes         Tweeted from  \
# 0   2022-10-15  SurfaniSurfani3                0  Twitter for Android
# 1   2022-10-15      UmiHafizha1                1  Twitter for Android
# 2   2022-10-15    latifajulia77                1  Twitter for Android
# 3   2022-10-15        PDemokrat              142  Twitter for Android
# 4   2022-10-15      BELIEVEIN93                0  Twitter for Android
# 5   2022-10-15     icalgusdinar                0  Twitter for Android
# 6   2022-10-15    rzkyamaliyeah                0  Twitter for Android
# 7   2022-10-15      latifajulia                5  Twitter for Android
# 8   2022-10-15  Salsabi03621592                0  Twitter for Android
# 9   2022-10-15    executifmudaa                3  Twitter for Android
# 10  2022-10-15        zalva1924               25  Twitter for Android
# 11  2022-10-15         encielss                1  Twitter for Android
# 12  2022-10-15    Hidayah_ayya4                0      Twitter Web App
# 13  2022-10-15        julisuack                0  Twitter for Android
# 14  2022-10-15   LoudMinorities                3      Twitter Web App
# 15  2022-10-15        PPELBERRY                0  Twitter for Android
# 16  2022-10-15     Fatin_Nissa4                0      Twitter Web App
# 17  2022-10-15       kompasiana                0              dlvr.it
# 18  2022-10-15       tempodotco                3              dlvr.it
# 19  2022-10-15          UAsia18                0  Twitter for Android
#
#                                                                                                                                                                                                                                                                                                                     Tweets  \
# 0         seiring dg Resesi proyeksi gelap ekonomi global adlg kunci logis dri penerapan sistem ekonomi kapitalisme yg mulai menguasai dunia pd abad ke-18 Apalagi setelah Amerika menaklukkan Rival ideologix yaitu monarki,selengkapnya di serba-serbi MMC https://t.co/Ioec3Eczmr\n#IslamKaffah https://t.co/LwNSBD3klA
# 1                                IMF memproyeksi ekonomi global akan gelap pd tahun 2023. Hal ini diakibatkan oleh banyak hal, mulai dr resesi, COVID-19, imbas inv4si Rusi4 ke Ukr4ina, dll. Mampukah Sistem Ekonomi Kapitalisme mengatasinya? Simak videonya di Serba-serbi MMC\nhttps://t.co/rFNPpn7Cwx\n\n#IslamKaffah
# 2          ekonomi global Akan Gelap pd 2023 krn merugi 4T UD pd'26 akibat Resesi penyebabx setelah covid &amp; dihadapkan dg ancaman krisis imbas invasi Rusia ke Ukraina &amp; perubahan iklim,inilh akibt dri sistem ekonomi kapitalisme. Serba-serbi MMC https://t.co/ZLykApRMul\n#IslamKaffah https://t.co/4FKuVXUBUt
# 3   Presiden ke-6 RI, Susilo Bambang Yudhoyono merasa resah dgn resesi ekonomi dunia yg hambat upaya atasi global warming.\n\nDan dunia justru sibuk dgn masalah geopolitik &amp; ancaman resesi yg kian runcing. Lantas, seberapa besar perhatian para pemimpin dunia utk selamatkan bumi kita!?! https://t.co/7fvckgB6rG
# 4                                                                                                                                                                                            @jek___ Sebelum 2015 udha ngerasain resesi wkwkwk.. Bismillah siap menjalani dan menghadapinya lagi 🤟 https://t.co/u0zwoEIlfm
# 5                                                                                                                                                                                                                                                                               Saya yang dari lahir RESESI aja biasa aja.
# 6                                                                                                                                                                                                                                                         She said, tahun depan mau resesi loh, yakin mau resign?\nArghhhh
# 7                                                                                                  Ekonomi dunia diprediksi gelap pd 2023, mampukah kapitalisme mengatasi ekonomi kapitalis yg akan resesi thn depan?, simak selengkaonya di serba-serbi MMC https://t.co/vAdMqPfIgM\n#IslamKaffah https://t.co/jqTnaEQMn4
# 8                                                                                                                                                            Dunia sedang mengalami resesi yang diakibatkan penerapan sistem ekonomi kapitalisme. \nSimak Serba-serbi MMC berikut\nhttps://t.co/LA5WWJhfaH\n\n#IslamKaffah
# 9                                                                                                                                                                                        @votsssss_ Si anjing mending suruh kerja trus nabung tahun depan resesi soalnya🤣 war sama netijen gak bakal bikin tabungan gendut
# 10       Ekonomi Dunia Diprediksi Gelap pada 2023, Mampukah Kapitalisme Mengatasinya? | Serba-serbi MMC\n\nIMF memproyeksi ekonomi global akan gelap pada tahun 2023. Hal ini diakibatkan oleh banyak hal, mulai dari resesi, COVID-19, imbas inv4si Rusi4 ke Ukr4ina, \n\nhttps://t.co/VhAQjqZdRT https://t.co/KMYio4yc1i
# 11                                                                                                                                             thx bgt loh ini gue jadi paham dikit sm si resesi ini. semoga aku dan kita semua tahun depan aman aja ya. &amp; semoga bintang &amp; mares balikan. https://t.co/4FxLK69a7i
# 12                                           Ekonomi Dunia Diprediksi Gelap pada 2023 | Serba-serbi MMC\n\nIMF memproyeksi ekonomi global akan gelap pada tahun 2023. Hal ini diakibatkan oleh banyak hal, mulai dari resesi dll. Mampukah Sistem ekonomi kapitalisme mengatasinya?\nhttps://t.co/cIM9CoqJQK\nIslam kaffah
# 13                                                                                                                                                                                                                    buat klen yg ajak-ajak hangout sorry ya gue tolak soalnya lagi persiapan menghadapi resesi thn depan
# 14                                                                                               Bayangin kalo orang ini sampai jadi Presiden, trus Indonesia resesi, keluar statement "Saya bersyukur Indonesia masih kena resesi, karena di negara pedalaman Afrika orang gak bisa makan lho..." https://t.co/85qNKSYhrb
# 15                                                                                                                                                                                                                         Bener sih, tinggal menghadapi resesi seperti tahun tahun lainnya wkwkwk https://t.co/H9szcLWml9
# 16                                                            Ekonomi Dunia Diprediksi Gelap pada 2023, Mampukah Kapitalisme Mengatasinya? | Serba-serbi MMC\n\nIMF memproyeksi ekonomi global akan gelap pada tahun 2023. Hal ini diakibatkan oleh banyak hal, mulai dari resesi, \nhttps://t.co/mLmZplORvk\nIslam kaffah
# 17                                                                                                                                                                                                                                                             7 Kiat Bagi UMKM Hadapi Resesi 2023 https://t.co/6ky11QwUlb
# 18                                                                                                                                                                                                              Pakar Sebut Resesi Global Tak Berdampak Langsung ke RI, Ini Alasannya https://t.co/vbjMstJJ5U #TempoBisnis
# 19                                                                                                                         ngapain mesti takut sih sama prediksi resesi 2023\n\nemang selama ini hidupmu gak sulit? emang sekarang penghasilanmu banyak? dari dulu juga antum udah resesi duluan jadi ngapain takut ye gak
#
#                                                                                                                                                                                                                                                     clear  \
# 0                             seiring dg resesi proyeksi gelap ekonomi global adlg kunci logis dri penerapan sistem ekonomi kapitalisme mulai menguasai dunia abad apalagi amerika menaklukkan rival ideologix monarkiselengkapnya serbaserbi islamkaffah
# 1                                                 imf memproyeksi ekonomi global gelap tahun ini diakibatkan banyak mulai resesi covid imbas invsi rusi ukrina mampukah sistem ekonomi kapitalisme mengatasinya simak videonya serbaserbi mmc islamkaffah
# 2                                     ekonomi global gelap krn merugi t ud akibat resesi penyebabx covid amp dihadapkan dg ancaman krisis imbas invasi rusia ukraina amp perubahan ikliminilh akibt dri sistem ekonomi kapitalisme serbaserbi islamkaffah
# 3   presiden ri susilo bambang yudhoyono merasa resah resesi ekonomi dunia hambat upaya atasi global warming dan dunia justru sibuk masalah geopolitik amp ancaman resesi kian runcing lantas seberapa besar perhatian pemimpin dunia utk selamatkan bumi
# 4                                                                                                                                                                                     udha ngerasain resesi wkwkwk bismillah siap menjalani menghadapinya
# 5                                                                                                                                                                                                                         yang lahir resesi aja biasa aja
# 6                                                                                                                                                                                            she said tahun depan mau resesi loh yakin mau resign arghhhh
# 7                                                                                                         ekonomi dunia diprediksi gelap mampukah kapitalisme mengatasi ekonomi kapitalis akan resesi thn depan simak selengkaonya serbaserbi islamkaffah
# 8                                                                                                                                     dunia sedang mengalami resesi diakibatkan penerapan sistem ekonomi kapitalisme simak serbaserbi berikut islamkaffah
# 9                                                                                                                                        si anjing mending suruh kerja nabung tahun depan resesi soalnya war sama netijen gak bakal bikin tabungan gendut
# 10                                                           ekonomi dunia diprediksi gelap mampukah kapitalisme mengatasinya serbaserbi mmc imf memproyeksi ekonomi global gelap tahun ini diakibatkan banyak mulai resesi covid imbas invsi rusi ukrina
# 11                                                                                                                              thx loh gue jadi paham dikit sm si resesi semoga aku kita semua tahun depan aman aja amp semoga bintang amp mares balikan
# 12                                                             ekonomi dunia diprediksi gelap serbaserbi mmc imf memproyeksi ekonomi global gelap tahun ini diakibatkan banyak mulai resesi mampukah sistem ekonomi kapitalisme mengatasinya islam kaffah
# 13                                                                                                                                                               buat klen ajakajak hangout sorry gue tolak soalnya persiapan menghadapi resesi thn depan
# 14                                                                                              bayangin kalo orang sampai jadi presiden indonesia resesi keluar statement bersyukur indonesia kena resesi di negara pedalaman afrika orang gak makan lho
# 15                                                                                                                                                                                         bener sih tinggal menghadapi resesi tahun tahun lainnya wkwkwk
# 16                                                                            ekonomi dunia diprediksi gelap mampukah kapitalisme mengatasinya serbaserbi mmc imf memproyeksi ekonomi global gelap tahun ini diakibatkan banyak mulai resesi islam kaffah
# 17                                                                                                                                                                                                                                kiat umkm hadapi resesi
# 18                                                                                                                                                                              pakar sebut resesi global tak berdampak langsung ri alasannya tempobisnis
# 19                                                                                ngapain mesti takut sih sama prediksi resesi emang selama hidupmu gak sulit emang sekarang penghasilanmu banyak dulu antum udah resesi duluan jadi ngapain takut ye gak
#
#                                                                                                                                                                                                                                                                                  token_tweets  \
# 0                                     [seiring, dg, resesi, proyeksi, gelap, ekonomi, global, adlg, kunci, logis, dri, penerapan, sistem, ekonomi, kapitalisme, mulai, menguasai, dunia, abad, apalagi, amerika, menaklukkan, rival, ideologix, monarkiselengkapnya, serbaserbi, islamkaffah]
# 1                                                          [imf, memproyeksi, ekonomi, global, gelap, tahun, ini, diakibatkan, banyak, mulai, resesi, covid, imbas, invsi, rusi, ukrina, mampukah, sistem, ekonomi, kapitalisme, mengatasinya, simak, videonya, serbaserbi, mmc, islamkaffah]
# 2                                          [ekonomi, global, gelap, krn, merugi, t, ud, akibat, resesi, penyebabx, covid, amp, dihadapkan, dg, ancaman, krisis, imbas, invasi, rusia, ukraina, amp, perubahan, ikliminilh, akibt, dri, sistem, ekonomi, kapitalisme, serbaserbi, islamkaffah]
# 3   [presiden, ri, susilo, bambang, yudhoyono, merasa, resah, resesi, ekonomi, dunia, hambat, upaya, atasi, global, warming, dan, dunia, justru, sibuk, masalah, geopolitik, amp, ancaman, resesi, kian, runcing, lantas, seberapa, besar, perhatian, pemimpin, dunia, utk, selamatkan, bumi]
# 4                                                                                                                                                                                                                [udha, ngerasain, resesi, wkwkwk, bismillah, siap, menjalani, menghadapinya]
# 5                                                                                                                                                                                                                                                      [yang, lahir, resesi, aja, biasa, aja]
# 6                                                                                                                                                                                                                    [she, said, tahun, depan, mau, resesi, loh, yakin, mau, resign, arghhhh]
# 7                                                                                                                           [ekonomi, dunia, diprediksi, gelap, mampukah, kapitalisme, mengatasi, ekonomi, kapitalis, akan, resesi, thn, depan, simak, selengkaonya, serbaserbi, islamkaffah]
# 8                                                                                                                                                           [dunia, sedang, mengalami, resesi, diakibatkan, penerapan, sistem, ekonomi, kapitalisme, simak, serbaserbi, berikut, islamkaffah]
# 9                                                                                                                                                         [si, anjing, mending, suruh, kerja, nabung, tahun, depan, resesi, soalnya, war, sama, netijen, gak, bakal, bikin, tabungan, gendut]
# 10                                                                     [ekonomi, dunia, diprediksi, gelap, mampukah, kapitalisme, mengatasinya, serbaserbi, mmc, imf, memproyeksi, ekonomi, global, gelap, tahun, ini, diakibatkan, banyak, mulai, resesi, covid, imbas, invsi, rusi, ukrina]
# 11                                                                                                                                          [thx, loh, gue, jadi, paham, dikit, sm, si, resesi, semoga, aku, kita, semua, tahun, depan, aman, aja, amp, semoga, bintang, amp, mares, balikan]
# 12                                                                        [ekonomi, dunia, diprediksi, gelap, serbaserbi, mmc, imf, memproyeksi, ekonomi, global, gelap, tahun, ini, diakibatkan, banyak, mulai, resesi, mampukah, sistem, ekonomi, kapitalisme, mengatasinya, islam, kaffah]
# 13                                                                                                                                                                                     [buat, klen, ajakajak, hangout, sorry, gue, tolak, soalnya, persiapan, menghadapi, resesi, thn, depan]
# 14                                                                                                           [bayangin, kalo, orang, sampai, jadi, presiden, indonesia, resesi, keluar, statement, bersyukur, indonesia, kena, resesi, di, negara, pedalaman, afrika, orang, gak, makan, lho]
# 15                                                                                                                                                                                                                   [bener, sih, tinggal, menghadapi, resesi, tahun, tahun, lainnya, wkwkwk]
# 16                                                                                         [ekonomi, dunia, diprediksi, gelap, mampukah, kapitalisme, mengatasinya, serbaserbi, mmc, imf, memproyeksi, ekonomi, global, gelap, tahun, ini, diakibatkan, banyak, mulai, resesi, islam, kaffah]
# 17                                                                                                                                                                                                                                                               [kiat, umkm, hadapi, resesi]
# 18                                                                                                                                                                                                       [pakar, sebut, resesi, global, tak, berdampak, langsung, ri, alasannya, tempobisnis]
# 19                                                                                         [ngapain, mesti, takut, sih, sama, prediksi, resesi, emang, selama, hidupmu, gak, sulit, emang, sekarang, penghasilanmu, banyak, dulu, antum, udah, resesi, duluan, jadi, ngapain, takut, ye, gak]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                              freq_words  \
# 0                                                      {'seiring': 1, 'dg': 1, 'resesi': 1, 'proyeksi': 1, 'gelap': 1, 'ekonomi': 2, 'global': 1, 'adlg': 1, 'kunci': 1, 'logis': 1, 'dri': 1, 'penerapan': 1, 'sistem': 1, 'kapitalisme': 1, 'mulai': 1, 'menguasai': 1, 'dunia': 1, 'abad': 1, 'apalagi': 1, 'amerika': 1, 'menaklukkan': 1, 'rival': 1, 'ideologix': 1, 'monarkiselengkapnya': 1, 'serbaserbi': 1, 'islamkaffah': 1}
# 1                                                                                {'imf': 1, 'memproyeksi': 1, 'ekonomi': 2, 'global': 1, 'gelap': 1, 'tahun': 1, 'ini': 1, 'diakibatkan': 1, 'banyak': 1, 'mulai': 1, 'resesi': 1, 'covid': 1, 'imbas': 1, 'invsi': 1, 'rusi': 1, 'ukrina': 1, 'mampukah': 1, 'sistem': 1, 'kapitalisme': 1, 'mengatasinya': 1, 'simak': 1, 'videonya': 1, 'serbaserbi': 1, 'mmc': 1, 'islamkaffah': 1}
# 2                                                      {'ekonomi': 2, 'global': 1, 'gelap': 1, 'krn': 1, 'merugi': 1, 't': 1, 'ud': 1, 'akibat': 1, 'resesi': 1, 'penyebabx': 1, 'covid': 1, 'amp': 2, 'dihadapkan': 1, 'dg': 1, 'ancaman': 1, 'krisis': 1, 'imbas': 1, 'invasi': 1, 'rusia': 1, 'ukraina': 1, 'perubahan': 1, 'ikliminilh': 1, 'akibt': 1, 'dri': 1, 'sistem': 1, 'kapitalisme': 1, 'serbaserbi': 1, 'islamkaffah': 1}
# 3   {'presiden': 1, 'ri': 1, 'susilo': 1, 'bambang': 1, 'yudhoyono': 1, 'merasa': 1, 'resah': 1, 'resesi': 2, 'ekonomi': 1, 'dunia': 3, 'hambat': 1, 'upaya': 1, 'atasi': 1, 'global': 1, 'warming': 1, 'dan': 1, 'justru': 1, 'sibuk': 1, 'masalah': 1, 'geopolitik': 1, 'amp': 1, 'ancaman': 1, 'kian': 1, 'runcing': 1, 'lantas': 1, 'seberapa': 1, 'besar': 1, 'perhatian': 1, 'pemimpin': 1, 'utk': 1, 'selamatkan': 1, 'bumi': 1}
# 4                                                                                                                                                                                                                                                                                                                  {'udha': 1, 'ngerasain': 1, 'resesi': 1, 'wkwkwk': 1, 'bismillah': 1, 'siap': 1, 'menjalani': 1, 'menghadapinya': 1}
# 5                                                                                                                                                                                                                                                                                                                                                                            {'yang': 1, 'lahir': 1, 'resesi': 1, 'aja': 2, 'biasa': 1}
# 6                                                                                                                                                                                                                                                                                                                 {'she': 1, 'said': 1, 'tahun': 1, 'depan': 1, 'mau': 2, 'resesi': 1, 'loh': 1, 'yakin': 1, 'resign': 1, 'arghhhh': 1}
# 7                                                                                                                                                                                              {'ekonomi': 2, 'dunia': 1, 'diprediksi': 1, 'gelap': 1, 'mampukah': 1, 'kapitalisme': 1, 'mengatasi': 1, 'kapitalis': 1, 'akan': 1, 'resesi': 1, 'thn': 1, 'depan': 1, 'simak': 1, 'selengkaonya': 1, 'serbaserbi': 1, 'islamkaffah': 1}
# 8                                                                                                                                                                                                                                    {'dunia': 1, 'sedang': 1, 'mengalami': 1, 'resesi': 1, 'diakibatkan': 1, 'penerapan': 1, 'sistem': 1, 'ekonomi': 1, 'kapitalisme': 1, 'simak': 1, 'serbaserbi': 1, 'berikut': 1, 'islamkaffah': 1}
# 9                                                                                                                                                                                                         {'si': 1, 'anjing': 1, 'mending': 1, 'suruh': 1, 'kerja': 1, 'nabung': 1, 'tahun': 1, 'depan': 1, 'resesi': 1, 'soalnya': 1, 'war': 1, 'sama': 1, 'netijen': 1, 'gak': 1, 'bakal': 1, 'bikin': 1, 'tabungan': 1, 'gendut': 1}
# 10                                                                                                            {'ekonomi': 2, 'dunia': 1, 'diprediksi': 1, 'gelap': 2, 'mampukah': 1, 'kapitalisme': 1, 'mengatasinya': 1, 'serbaserbi': 1, 'mmc': 1, 'imf': 1, 'memproyeksi': 1, 'global': 1, 'tahun': 1, 'ini': 1, 'diakibatkan': 1, 'banyak': 1, 'mulai': 1, 'resesi': 1, 'covid': 1, 'imbas': 1, 'invsi': 1, 'rusi': 1, 'ukrina': 1}
# 11                                                                                                                                                                                        {'thx': 1, 'loh': 1, 'gue': 1, 'jadi': 1, 'paham': 1, 'dikit': 1, 'sm': 1, 'si': 1, 'resesi': 1, 'semoga': 2, 'aku': 1, 'kita': 1, 'semua': 1, 'tahun': 1, 'depan': 1, 'aman': 1, 'aja': 1, 'amp': 2, 'bintang': 1, 'mares': 1, 'balikan': 1}
# 12                                                                                                                                  {'ekonomi': 3, 'dunia': 1, 'diprediksi': 1, 'gelap': 2, 'serbaserbi': 1, 'mmc': 1, 'imf': 1, 'memproyeksi': 1, 'global': 1, 'tahun': 1, 'ini': 1, 'diakibatkan': 1, 'banyak': 1, 'mulai': 1, 'resesi': 1, 'mampukah': 1, 'sistem': 1, 'kapitalisme': 1, 'mengatasinya': 1, 'islam': 1, 'kaffah': 1}
# 13                                                                                                                                                                                                                                                              {'buat': 1, 'klen': 1, 'ajakajak': 1, 'hangout': 1, 'sorry': 1, 'gue': 1, 'tolak': 1, 'soalnya': 1, 'persiapan': 1, 'menghadapi': 1, 'resesi': 1, 'thn': 1, 'depan': 1}
# 14                                                                                                                                                                                {'bayangin': 1, 'kalo': 1, 'orang': 2, 'sampai': 1, 'jadi': 1, 'presiden': 1, 'indonesia': 2, 'resesi': 2, 'keluar': 1, 'statement': 1, 'bersyukur': 1, 'kena': 1, 'di': 1, 'negara': 1, 'pedalaman': 1, 'afrika': 1, 'gak': 1, 'makan': 1, 'lho': 1}
# 15                                                                                                                                                                                                                                                                                                                            {'bener': 1, 'sih': 1, 'tinggal': 1, 'menghadapi': 1, 'resesi': 1, 'tahun': 2, 'lainnya': 1, 'wkwkwk': 1}
# 16                                                                                                                                               {'ekonomi': 2, 'dunia': 1, 'diprediksi': 1, 'gelap': 2, 'mampukah': 1, 'kapitalisme': 1, 'mengatasinya': 1, 'serbaserbi': 1, 'mmc': 1, 'imf': 1, 'memproyeksi': 1, 'global': 1, 'tahun': 1, 'ini': 1, 'diakibatkan': 1, 'banyak': 1, 'mulai': 1, 'resesi': 1, 'islam': 1, 'kaffah': 1}
# 17                                                                                                                                                                                                                                                                                                                                                                                     {'kiat': 1, 'umkm': 1, 'hadapi': 1, 'resesi': 1}
# 18                                                                                                                                                                                                                                                                                               {'pakar': 1, 'sebut': 1, 'resesi': 1, 'global': 1, 'tak': 1, 'berdampak': 1, 'langsung': 1, 'ri': 1, 'alasannya': 1, 'tempobisnis': 1}
# 19                                                                                                                                                              {'ngapain': 2, 'mesti': 1, 'takut': 2, 'sih': 1, 'sama': 1, 'prediksi': 1, 'resesi': 2, 'emang': 2, 'selama': 1, 'hidupmu': 1, 'gak': 2, 'sulit': 1, 'sekarang': 1, 'penghasilanmu': 1, 'banyak': 1, 'dulu': 1, 'antum': 1, 'udah': 1, 'duluan': 1, 'jadi': 1, 'ye': 1}
#
#                                                                                                                                                                                                                                                                   stemmed_tweet  \
# 0                                      [iring, dg, resesi, proyeksi, gelap, ekonomi, global, adlg, kunci, logis, dri, terap, sistem, ekonomi, kapitalisme, mulai, kuasa, dunia, abad, apalagi, amerika, takluk, rival, ideologix, monarkiselengkapnya, serbaserbi, islamkaffah]
# 1                                                                  [imf, proyeksi, ekonomi, global, gelap, tahun, ini, akibat, banyak, mulai, resesi, covid, imbas, invsi, rusi, ukrina, mampu, sistem, ekonomi, kapitalisme, atas, simak, video, serbaserbi, mmc, islamkaffah]
# 2                                          [ekonomi, global, gelap, krn, rugi, t, ud, akibat, resesi, penyebabx, covid, amp, hadap, dg, ancam, krisis, imbas, invasi, rusia, ukraina, amp, ubah, ikliminilh, akibt, dri, sistem, ekonomi, kapitalisme, serbaserbi, islamkaffah]
# 3   [presiden, ri, susilo, bambang, yudhoyono, rasa, resah, resesi, ekonomi, dunia, hambat, upaya, atas, global, warming, dan, dunia, justru, sibuk, masalah, geopolitik, amp, ancam, resesi, kian, runcing, lantas, berapa, besar, perhati, pimpin, dunia, utk, selamat, bumi]
# 4                                                                                                                                                                                                              [udha, ngerasain, resesi, wkwkwk, bismillah, siap, jalan, hadap]
# 5                                                                                                                                                                                                                                        [yang, lahir, resesi, aja, biasa, aja]
# 6                                                                                                                                                                                                      [she, said, tahun, depan, mau, resesi, loh, yakin, mau, resign, arghhhh]
# 7                                                                                                                       [ekonomi, dunia, prediksi, gelap, mampu, kapitalisme, atas, ekonomi, kapitalis, akan, resesi, thn, depan, simak, selengkaonya, serbaserbi, islamkaffah]
# 8                                                                                                                                                             [dunia, sedang, alami, resesi, akibat, terap, sistem, ekonomi, kapitalisme, simak, serbaserbi, ikut, islamkaffah]
# 9                                                                                                                                                [si, anjing, mending, suruh, kerja, nabung, tahun, depan, resesi, soal, war, sama, netijen, gak, bakal, bikin, tabung, gendut]
# 10                                                                            [ekonomi, dunia, prediksi, gelap, mampu, kapitalisme, atas, serbaserbi, mmc, imf, proyeksi, ekonomi, global, gelap, tahun, ini, akibat, banyak, mulai, resesi, covid, imbas, invsi, rusi, ukrina]
# 11                                                                                                                                  [thx, loh, gue, jadi, paham, dikit, sm, si, resesi, moga, aku, kita, semua, tahun, depan, aman, aja, amp, moga, bintang, amp, mares, balik]
# 12                                                                               [ekonomi, dunia, prediksi, gelap, serbaserbi, mmc, imf, proyeksi, ekonomi, global, gelap, tahun, ini, akibat, banyak, mulai, resesi, mampu, sistem, ekonomi, kapitalisme, atas, islam, kaffah]
# 13                                                                                                                                                                                    [buat, klen, ajakajak, hangout, sorry, gue, tolak, soal, siap, hadap, resesi, thn, depan]
# 14                                                                                                    [bayangin, kalo, orang, sampai, jadi, presiden, indonesia, resesi, keluar, statement, syukur, indonesia, kena, resesi, di, negara, dalam, afrika, orang, gak, makan, lho]
# 15                                                                                                                                                                                                             [bener, sih, tinggal, hadap, resesi, tahun, tahun, lain, wkwkwk]
# 16                                                                                                [ekonomi, dunia, prediksi, gelap, mampu, kapitalisme, atas, serbaserbi, mmc, imf, proyeksi, ekonomi, global, gelap, tahun, ini, akibat, banyak, mulai, resesi, islam, kaffah]
# 17                                                                                                                                                                                                                                                  [kiat, umkm, hadap, resesi]
# 18                                                                                                                                                                                                 [pakar, sebut, resesi, global, tak, dampak, langsung, ri, alas, tempobisnis]
# 19                                                                                       [ngapain, mesti, takut, sih, sama, prediksi, resesi, emang, lama, hidup, gak, sulit, emang, sekarang, hasil, banyak, dulu, antum, udah, resesi, duluan, jadi, ngapain, takut, ye, gak]
#
#     polarity_score  polarity  score
# 0               -8  negative     -1
# 1              -15  negative     -1
# 2              -25  negative     -1
# 3              -29  negative     -1
# 4                5  positive      1
# 5               -7  negative     -1
# 6                6  positive      1
# 7               -9  negative     -1
# 8               -9  negative     -1
# 9              -11  negative     -1
# 10             -14  negative     -1
# 11             -11  negative     -1
# 12             -10  negative     -1
# 13             -11  negative     -1
# 14             -11  negative     -1
# 15              -2  negative     -1
# 16              -6  negative     -1
# 17              -2  negative     -1
# 18              -3  negative     -1
# 19             -15  negative     -1

# %%
by_day = pd.to_datetime(df_final['Date']).dt.to_period('D').value_counts().sort_index()
by_day.index = pd.PeriodIndex(by_day.index)
df_day = by_day.rename_axis('day').reset_index(name='counts')
df_day
# Out:
#           day  counts
# 0  2022-10-11    1532
# 1  2022-10-12    1381
# 2  2022-10-13    1246
# 3  2022-10-14    1939
# 4  2022-10-15    1187

# %%
df_day.sort_values(by='counts', ascending=False)
# Out:
#           day  counts
# 3  2022-10-14    1939
# 0  2022-10-11    1532
# 1  2022-10-12    1381
# 2  2022-10-13    1246
# 4  2022-10-15    1187

# %%
df_day.info
# Out:
# <bound method DataFrame.info of           day  counts
# 0  2022-10-11    1532
# 1  2022-10-12    1381
# 2  2022-10-13    1246
# 3  2022-10-14    1939
# 4  2022-10-15    1187>

# %%
pd.plotting.register_matplotlib_converters()

# %%
## plot results ##
f = plt.figure()
f.set_figwidth(8)
f.set_figheight(4)
plt.plot(df_day.index,df_day.counts)
plt.xticks(df_day.index,df_day.day)
# plt.xticks(rotation = 90)
# plt.legend()
plt.ylabel('# of tweets')
plt.xlabel("time")
plt.show()

# %%
df_freq = pd.DataFrame(list(all_freq_words.items()), columns = ["Word","Frequency"]).sort_values(by='Frequency', ascending=False)
data_freq = df_freq
data_freq.head()
# Out:
#        Word  Frequency
# 2    resesi       8338
# 5   ekonomi       1313
# 28    tahun       1197
# 97    depan       1075
# 6    global        842

# %%
all_freq_words
# Out:
# FreqDist({'resesi': 8338, 'ekonomi': 1313, 'tahun': 1197, 'depan': 1075, 'global': 842, 'aja': 813, 'mau': 788, 'indonesia': 713, 'dunia': 618, 'apa': 583, ...})

# %%
# Read CSV into pandas
# data = pd.read_csv(r"cars.csv")
# data.head()
# df = pd.DataFrame(data)
colors = ['green', 'yellow', 'grey', 'blue', 'red', 'orange','purple','black','brown','pink']
word = data_freq['Word'][0:10].values.tolist()
freq = data_freq['Frequency'][0:10].values.tolist()
 
# Figure Size
fig = plt.figure(figsize =(10, 7))

# Horizontal Bar Plot
ax=plt.bar(word, freq, color=colors)
plt.bar_label(ax,labels=freq)

plt.legend(ax,word, loc="best")
plt.show()

 
# Show Plot

# %% [markdown]
# NAIVE BAYES (clasisikasi)

# %%
df_final
# Out:
#             Date             User  Number of likes         Tweeted from  \
# 0     2022-10-15  SurfaniSurfani3                0  Twitter for Android
# 1     2022-10-15      UmiHafizha1                1  Twitter for Android
# 2     2022-10-15    latifajulia77                1  Twitter for Android
# 3     2022-10-15        PDemokrat              142  Twitter for Android
# 4     2022-10-15      BELIEVEIN93                0  Twitter for Android
# ...          ...              ...              ...                  ...
# 7609  2022-10-11      b1ngchillin                0   Twitter for iPhone
# 7611  2022-10-11       ghaits_ali                0              dlvr.it
# 7613  2022-10-11     RadioSmartFM                0            TweetDeck
# 7614  2022-10-11      sugarhnybee                0  Twitter for Android
# 7615  2022-10-11        tvOneNews                2              dlvr.it
#
#                                                                                                                                                                                                                                                                                                                       Tweets  \
# 0           seiring dg Resesi proyeksi gelap ekonomi global adlg kunci logis dri penerapan sistem ekonomi kapitalisme yg mulai menguasai dunia pd abad ke-18 Apalagi setelah Amerika menaklukkan Rival ideologix yaitu monarki,selengkapnya di serba-serbi MMC https://t.co/Ioec3Eczmr\n#IslamKaffah https://t.co/LwNSBD3klA
# 1                                  IMF memproyeksi ekonomi global akan gelap pd tahun 2023. Hal ini diakibatkan oleh banyak hal, mulai dr resesi, COVID-19, imbas inv4si Rusi4 ke Ukr4ina, dll. Mampukah Sistem Ekonomi Kapitalisme mengatasinya? Simak videonya di Serba-serbi MMC\nhttps://t.co/rFNPpn7Cwx\n\n#IslamKaffah
# 2            ekonomi global Akan Gelap pd 2023 krn merugi 4T UD pd'26 akibat Resesi penyebabx setelah covid &amp; dihadapkan dg ancaman krisis imbas invasi Rusia ke Ukraina &amp; perubahan iklim,inilh akibt dri sistem ekonomi kapitalisme. Serba-serbi MMC https://t.co/ZLykApRMul\n#IslamKaffah https://t.co/4FKuVXUBUt
# 3     Presiden ke-6 RI, Susilo Bambang Yudhoyono merasa resah dgn resesi ekonomi dunia yg hambat upaya atasi global warming.\n\nDan dunia justru sibuk dgn masalah geopolitik &amp; ancaman resesi yg kian runcing. Lantas, seberapa besar perhatian para pemimpin dunia utk selamatkan bumi kita!?! https://t.co/7fvckgB6rG
# 4                                                                                                                                                                                              @jek___ Sebelum 2015 udha ngerasain resesi wkwkwk.. Bismillah siap menjalani dan menghadapinya lagi 🤟 https://t.co/u0zwoEIlfm
# ...                                                                                                                                                                                                                                                                                                                      ...
# 7609                                                                                                                                                                                                            persiapan resesi kontol how can i persiapin duit ajggg dimana gaji gue aja lebih kecil dr pengeluaran satttt
# 7611                                                                                                                                                                                                                      Harga Minyak Jatuh Karena Kekhawatiran Resesi Lebihi Prospek Pasokan Ketat https://t.co/lZbSwcF38T
# 7613                                                                                                                                             NOW AIRING\n\n#SmartBusinessTalk bersama @TungDW\n\nyang membahas topik mengenai "Kondisi Ekonomi Indonesia dengan Resesi Global 2023" sampai pukul 08.00 WIB\n\nStay tuned
# 7614                                                                                                                                                                                                                               Kalo amit2 jadi resesi yg mo nikah tahun depan gmn ya, milih gajadi apa kyk pas covid (?)
# 7615                                                                                                                                                                           Harga Minyak Merosot Hampir Dua Persen Pada Akhir Perdagangan Karena Kekhawatiran Resesi Lebihi Prospek Pasokan Ketat https://t.co/CAKR2OtlnC
#
#                                                                                                                                                                                                                                                       clear  \
# 0                               seiring dg resesi proyeksi gelap ekonomi global adlg kunci logis dri penerapan sistem ekonomi kapitalisme mulai menguasai dunia abad apalagi amerika menaklukkan rival ideologix monarkiselengkapnya serbaserbi islamkaffah
# 1                                                   imf memproyeksi ekonomi global gelap tahun ini diakibatkan banyak mulai resesi covid imbas invsi rusi ukrina mampukah sistem ekonomi kapitalisme mengatasinya simak videonya serbaserbi mmc islamkaffah
# 2                                       ekonomi global gelap krn merugi t ud akibat resesi penyebabx covid amp dihadapkan dg ancaman krisis imbas invasi rusia ukraina amp perubahan ikliminilh akibt dri sistem ekonomi kapitalisme serbaserbi islamkaffah
# 3     presiden ri susilo bambang yudhoyono merasa resah resesi ekonomi dunia hambat upaya atasi global warming dan dunia justru sibuk masalah geopolitik amp ancaman resesi kian runcing lantas seberapa besar perhatian pemimpin dunia utk selamatkan bumi
# 4                                                                                                                                                                                       udha ngerasain resesi wkwkwk bismillah siap menjalani menghadapinya
# ...                                                                                                                                                                                                                                                     ...
# 7609                                                                                                                                                     persiapan resesi kontol how can i persiapin duit ajggg gaji gue aja lebih kecil pengeluaran satttt
# 7611                                                                                                                                                                                    harga minyak jatuh kekhawatiran resesi lebihi prospek pasokan ketat
# 7613                                                                                                                         now airing smartbusinesstalk bersama yang membahas topik mengenai kondisi ekonomi indonesia resesi global pukul wib stay tuned
# 7614                                                                                                                                                                          kalo amit jadi resesi mo nikah tahun depan gmn milih gajadi apa kyk pas covid
# 7615                                                                                                                                                  harga minyak merosot hampir persen akhir perdagangan kekhawatiran resesi lebihi prospek pasokan ketat
#
#                                                                                                                                                                                                                                                                                    token_tweets  \
# 0                                       [seiring, dg, resesi, proyeksi, gelap, ekonomi, global, adlg, kunci, logis, dri, penerapan, sistem, ekonomi, kapitalisme, mulai, menguasai, dunia, abad, apalagi, amerika, menaklukkan, rival, ideologix, monarkiselengkapnya, serbaserbi, islamkaffah]
# 1                                                            [imf, memproyeksi, ekonomi, global, gelap, tahun, ini, diakibatkan, banyak, mulai, resesi, covid, imbas, invsi, rusi, ukrina, mampukah, sistem, ekonomi, kapitalisme, mengatasinya, simak, videonya, serbaserbi, mmc, islamkaffah]
# 2                                            [ekonomi, global, gelap, krn, merugi, t, ud, akibat, resesi, penyebabx, covid, amp, dihadapkan, dg, ancaman, krisis, imbas, invasi, rusia, ukraina, amp, perubahan, ikliminilh, akibt, dri, sistem, ekonomi, kapitalisme, serbaserbi, islamkaffah]
# 3     [presiden, ri, susilo, bambang, yudhoyono, merasa, resah, resesi, ekonomi, dunia, hambat, upaya, atasi, global, warming, dan, dunia, justru, sibuk, masalah, geopolitik, amp, ancaman, resesi, kian, runcing, lantas, seberapa, besar, perhatian, pemimpin, dunia, utk, selamatkan, bumi]
# 4                                                                                                                                                                                                                  [udha, ngerasain, resesi, wkwkwk, bismillah, siap, menjalani, menghadapinya]
# ...                                                                                                                                                                                                                                                                                         ...
# 7609                                                                                                                                                                        [persiapan, resesi, kontol, how, can, i, persiapin, duit, ajggg, gaji, gue, aja, lebih, kecil, pengeluaran, satttt]
# 7611                                                                                                                                                                                                              [harga, minyak, jatuh, kekhawatiran, resesi, lebihi, prospek, pasokan, ketat]
# 7613                                                                                                                                           [now, airing, smartbusinesstalk, bersama, yang, membahas, topik, mengenai, kondisi, ekonomi, indonesia, resesi, global, pukul, wib, stay, tuned]
# 7614                                                                                                                                                                                              [kalo, amit, jadi, resesi, mo, nikah, tahun, depan, gmn, milih, gajadi, apa, kyk, pas, covid]
# 7615                                                                                                                                                                        [harga, minyak, merosot, hampir, persen, akhir, perdagangan, kekhawatiran, resesi, lebihi, prospek, pasokan, ketat]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                freq_words  \
# 0                                                        {'seiring': 1, 'dg': 1, 'resesi': 1, 'proyeksi': 1, 'gelap': 1, 'ekonomi': 2, 'global': 1, 'adlg': 1, 'kunci': 1, 'logis': 1, 'dri': 1, 'penerapan': 1, 'sistem': 1, 'kapitalisme': 1, 'mulai': 1, 'menguasai': 1, 'dunia': 1, 'abad': 1, 'apalagi': 1, 'amerika': 1, 'menaklukkan': 1, 'rival': 1, 'ideologix': 1, 'monarkiselengkapnya': 1, 'serbaserbi': 1, 'islamkaffah': 1}
# 1                                                                                  {'imf': 1, 'memproyeksi': 1, 'ekonomi': 2, 'global': 1, 'gelap': 1, 'tahun': 1, 'ini': 1, 'diakibatkan': 1, 'banyak': 1, 'mulai': 1, 'resesi': 1, 'covid': 1, 'imbas': 1, 'invsi': 1, 'rusi': 1, 'ukrina': 1, 'mampukah': 1, 'sistem': 1, 'kapitalisme': 1, 'mengatasinya': 1, 'simak': 1, 'videonya': 1, 'serbaserbi': 1, 'mmc': 1, 'islamkaffah': 1}
# 2                                                        {'ekonomi': 2, 'global': 1, 'gelap': 1, 'krn': 1, 'merugi': 1, 't': 1, 'ud': 1, 'akibat': 1, 'resesi': 1, 'penyebabx': 1, 'covid': 1, 'amp': 2, 'dihadapkan': 1, 'dg': 1, 'ancaman': 1, 'krisis': 1, 'imbas': 1, 'invasi': 1, 'rusia': 1, 'ukraina': 1, 'perubahan': 1, 'ikliminilh': 1, 'akibt': 1, 'dri': 1, 'sistem': 1, 'kapitalisme': 1, 'serbaserbi': 1, 'islamkaffah': 1}
# 3     {'presiden': 1, 'ri': 1, 'susilo': 1, 'bambang': 1, 'yudhoyono': 1, 'merasa': 1, 'resah': 1, 'resesi': 2, 'ekonomi': 1, 'dunia': 3, 'hambat': 1, 'upaya': 1, 'atasi': 1, 'global': 1, 'warming': 1, 'dan': 1, 'justru': 1, 'sibuk': 1, 'masalah': 1, 'geopolitik': 1, 'amp': 1, 'ancaman': 1, 'kian': 1, 'runcing': 1, 'lantas': 1, 'seberapa': 1, 'besar': 1, 'perhatian': 1, 'pemimpin': 1, 'utk': 1, 'selamatkan': 1, 'bumi': 1}
# 4                                                                                                                                                                                                                                                                                                                    {'udha': 1, 'ngerasain': 1, 'resesi': 1, 'wkwkwk': 1, 'bismillah': 1, 'siap': 1, 'menjalani': 1, 'menghadapinya': 1}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 7609                                                                                                                                                                                                                                  {'persiapan': 1, 'resesi': 1, 'kontol': 1, 'how': 1, 'can': 1, 'i': 1, 'persiapin': 1, 'duit': 1, 'ajggg': 1, 'gaji': 1, 'gue': 1, 'aja': 1, 'lebih': 1, 'kecil': 1, 'pengeluaran': 1, 'satttt': 1}
# 7611                                                                                                                                                                                                                                                                                                           {'harga': 1, 'minyak': 1, 'jatuh': 1, 'kekhawatiran': 1, 'resesi': 1, 'lebihi': 1, 'prospek': 1, 'pasokan': 1, 'ketat': 1}
# 7613                                                                                                                                                                                                {'now': 1, 'airing': 1, 'smartbusinesstalk': 1, 'bersama': 1, 'yang': 1, 'membahas': 1, 'topik': 1, 'mengenai': 1, 'kondisi': 1, 'ekonomi': 1, 'indonesia': 1, 'resesi': 1, 'global': 1, 'pukul': 1, 'wib': 1, 'stay': 1, 'tuned': 1}
# 7614                                                                                                                                                                                                                                                             {'kalo': 1, 'amit': 1, 'jadi': 1, 'resesi': 1, 'mo': 1, 'nikah': 1, 'tahun': 1, 'depan': 1, 'gmn': 1, 'milih': 1, 'gajadi': 1, 'apa': 1, 'kyk': 1, 'pas': 1, 'covid': 1}
# 7615                                                                                                                                                                                                                                                 {'harga': 1, 'minyak': 1, 'merosot': 1, 'hampir': 1, 'persen': 1, 'akhir': 1, 'perdagangan': 1, 'kekhawatiran': 1, 'resesi': 1, 'lebihi': 1, 'prospek': 1, 'pasokan': 1, 'ketat': 1}
#
#                                                                                                                                                                                                                                                                     stemmed_tweet  \
# 0                                        [iring, dg, resesi, proyeksi, gelap, ekonomi, global, adlg, kunci, logis, dri, terap, sistem, ekonomi, kapitalisme, mulai, kuasa, dunia, abad, apalagi, amerika, takluk, rival, ideologix, monarkiselengkapnya, serbaserbi, islamkaffah]
# 1                                                                    [imf, proyeksi, ekonomi, global, gelap, tahun, ini, akibat, banyak, mulai, resesi, covid, imbas, invsi, rusi, ukrina, mampu, sistem, ekonomi, kapitalisme, atas, simak, video, serbaserbi, mmc, islamkaffah]
# 2                                            [ekonomi, global, gelap, krn, rugi, t, ud, akibat, resesi, penyebabx, covid, amp, hadap, dg, ancam, krisis, imbas, invasi, rusia, ukraina, amp, ubah, ikliminilh, akibt, dri, sistem, ekonomi, kapitalisme, serbaserbi, islamkaffah]
# 3     [presiden, ri, susilo, bambang, yudhoyono, rasa, resah, resesi, ekonomi, dunia, hambat, upaya, atas, global, warming, dan, dunia, justru, sibuk, masalah, geopolitik, amp, ancam, resesi, kian, runcing, lantas, berapa, besar, perhati, pimpin, dunia, utk, selamat, bumi]
# 4                                                                                                                                                                                                                [udha, ngerasain, resesi, wkwkwk, bismillah, siap, jalan, hadap]
# ...                                                                                                                                                                                                                                                                           ...
# 7609                                                                                                                                                                    [siap, resesi, kontol, how, can, i, persiapin, duit, ajggg, gaji, gue, aja, lebih, kecil, keluar, satttt]
# 7611                                                                                                                                                                                                       [harga, minyak, jatuh, khawatir, resesi, lebih, prospek, pasok, ketat]
# 7613                                                                                                                                       [now, airing, smartbusinesstalk, sama, yang, bahas, topik, kena, kondisi, ekonomi, indonesia, resesi, global, pukul, wib, stay, tuned]
# 7614                                                                                                                                                                                [kalo, amit, jadi, resesi, mo, nikah, tahun, depan, gmn, milih, gajadi, apa, kyk, pas, covid]
# 7615                                                                                                                                                                      [harga, minyak, merosot, hampir, persen, akhir, dagang, khawatir, resesi, lebih, prospek, pasok, ketat]
#
#       polarity_score  polarity  score
# 0                 -8  negative     -1
# 1                -15  negative     -1
# 2                -25  negative     -1
# 3                -29  negative     -1
# 4                  5  positive      1
# ...              ...       ...    ...
# 7609             -12  negative     -1
# 7611             -11  negative     -1
# 7613              -9  negative     -1
# 7614             -16  negative     -1
# 7615             -12  negative     -1
#
# [7285 rows x 12 columns]

# %%
X = df_final['clear']
Y = df_final['score']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2,random_state=0)

# %%
#TF-IDF vectorization of text

tfidf_vectorizer = TfidfVectorizer() 
tfidf_train_vectors = tfidf_vectorizer.fit_transform(X_train) 
tfidf_test_vectors = tfidf_vectorizer.transform(X_test)
print("n_samples: %d, n_features: %d" % tfidf_train_vectors.shape)
# Out:
# n_samples: 5828, n_features: 12827

# %%
tfidf_train_vectors.shape
# Out:
# (5828, 12827)

# %%
# SMOTA ALGORITHM
print("Before OverSampling, counts of label '1': {}".format(sum(Y_train == 1)))
print("Before OverSampling, counts of label '0': {}".format(sum(Y_train == 0)))
print("Before OverSampling, counts of label '-1': {} \n".format(sum(Y_train == -1)))

vectorizer = CountVectorizer()
vectorizer.fit(X_train.values.ravel())
cv_X_train=vectorizer.transform(X_train.values.ravel())
cv_X_test=vectorizer.transform(X_test.values.ravel())
cv_X_train=cv_X_train.toarray()
cv_X_test=cv_X_test.toarray()

# # import SMOTE module from imblearn 
# # pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_resample(cv_X_train, Y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
print("After OverSampling, counts of label '-1': {}".format(sum(y_train_res == -1)))
# Out:
# Before OverSampling, counts of label '1': 431
# Before OverSampling, counts of label '0': 136
# Before OverSampling, counts of label '-1': 5261
#
# After OverSampling, the shape of train_X: (15783, 12827)
# After OverSampling, the shape of train_y: (15783,)
#
# After OverSampling, counts of label '1': 5261
# After OverSampling, counts of label '0': 5261
# After OverSampling, counts of label '-1': 5261

# %%
#model training and prediction

naive_bayes_classifier = MultinomialNB()
naive_bayes_classifier.fit(X_train_res, y_train_res)

y_pred = naive_bayes_classifier.predict(tfidf_test_vectors)
print(classification_report(Y_test, y_pred)) #model evaluation
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.93      0.92      0.92      1326
#            0       0.02      0.02      0.02        43
#            1       0.26      0.28      0.27        88
#
#     accuracy                           0.86      1457
#    macro avg       0.40      0.41      0.41      1457
# weighted avg       0.86      0.86      0.86      1457

# %%
sum(y_pred==-0)
# Out:
# 45

# %%
print('Test accuracy = ', round(accuracy_score(Y_test, y_pred), 2))
# Out:
# Test accuracy =  0.86

# %%
cnf_mat = confusion_matrix(Y_test, y_pred)
cnf_mat #confusion_matrix
# Out:
# array([[1220,   41,   65],
#        [  37,    1,    5],
#        [  60,    3,   25]], dtype=int64)

# %%
sns.heatmap(cnf_mat, annot = True, fmt = '', cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
TP = np.diag(cnf_mat)
TP = TP.astype(float)
FN = cnf_mat.sum(axis = 1) - TP
FN = FN.astype(float)
FP = cnf_mat.sum(axis = 0) - TP 
FP = FP.astype(float)
TN = cnf_mat.sum() - (TP + FN + FP)
TN = TN.astype(float)

# Sensitivity
TPR = TP/(TP+FN)

# Specificity
TNR = TN/(TN+FP) 

#Precision
FPR = FP/(TN+FP)

# Overall accuracy for each class
ACC = (TP+TN)/(TP+FP+FN+TN)

# Classification error
Err = (FP+FN)/(TP+FP+FN+TN)

F1 =  2* ( FPR * TPR)/(FPR + TPR)

print('Recall = ', TPR.round(2))
print('Precision = ', FPR.round(2))
print('Accuracy = ', ACC.round(2))
print('Classification error = ', Err.round(2))
print('F1 Score = ', F1.round(2))
# Out:
# Recall =  [0.92 0.02 0.28]
# Precision =  [0.74 0.03 0.05]
# Accuracy =  [0.86 0.94 0.91]
# Classification error =  [0.14 0.06 0.09]
# F1 Score =  [0.82 0.03 0.09]

# %%
print(TP.round(2))
# [1.22e+03 1.00e+00 2.50e+01] 1220, 1, 25
print(TN)
print(FP)
print(FN)
# Out:
# [1.22e+03 1.00e+00 2.50e+01]
# [  34. 1370. 1299.]
# [97. 44. 70.]
# [106.  42.  63.]

# %% [markdown]
# LDA

# %%
df_final.head(3)

# %%
documents = []
texts = []

for tweet in df_final['token_tweets']:
#     document = description['token_tweets']
#     documents.append(document)
#     print(tweet)
    texts.append(tweet)
    documents.append(tweet)
print(documents[0])

# %%
dictionary = corpora.Dictionary(documents)

document_term = [dictionary.doc2bow(document) for document in documents]

# %%
ldamodel = models.ldamodel.LdaModel(document_term, num_topics=5, id2word = dictionary)

# %%
hasil_lda=ldamodel.print_topics(num_words=5)
hasil_lda

# %%
list_hasil=[]
for a in hasil_lda:
#     print(a[1].split('+'))
    list_a = [];
    for b in a[1].split('+'):
        list_a.append(b.split('*')[1].replace('"',"").replace(" ",""))
#         print(b.split('*')[1].replace('"',"").replace(" ",""))
#     print(list_a)
    list_hasil.append(list_a)
list_hasil

# %%
df_lda=pd.DataFrame(list_hasil)

# %%
# df_lda.T
df1_transposed = df_lda.T # or df1.transpose()

df1_transposed.columns = ['topik_1', 'topik_2','topik_3', 'topik_4','topik_5']
df1_transposed

# %% [markdown]
# dump model menggunakna library pickel

# %%
import pickle

# %%
with open('model1.pickle', 'wb') as file:
    pickle.dump(naive_bayes_classifier, file)

# %%
with open('model1.pickle', 'rb') as file:
    unpickled_data = pickle.load(file)

# %%
test_vectors = tfidf_vectorizer.transform(['chief henry salah satu yg disadari resesi menambah jumlah dana tunai cash nah dana tunai semakin banyak tinggal diversifikasi kemanfaatannya minimal manfaat manfaat dana darurat manfaat dana likuid manfaat perlundungan asuransi'])

# %%
result=unpickled_data.predict(test_vectors)
result[0]

# %%
print(np.argmax(y_pred>0))

# %%
result.index(-1)

# %%
X_test.iloc[2]
# Out:
# 'presiden partai buruh said iqbal menuturkan pihaknya turun jalan menolak adanya phk besarbesaran tengah ancaman resesi global'
